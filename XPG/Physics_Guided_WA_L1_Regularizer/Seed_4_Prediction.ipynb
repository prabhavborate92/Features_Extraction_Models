# %%
# Load libraries
import math
import sys
import h5py
import pandas as pd
import numpy as np
from numpy.fft import fft, ifft
from scipy import interpolate
import matplotlib.pyplot as plt
import pywt
from scipy.io import loadmat, savemat
from scipy import signal
from tensorflow.keras.optimizers import Adam, SGD
import tensorflow as tf
import keras.backend as K
from keras.models import Sequential,  Model
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from tensorflow.keras import layers
from tensorflow import keras
from keras.layers import MaxPooling2D, Conv2D, MaxPooling1D, Conv1D, Dense, Flatten, AveragePooling1D, LSTM, Dropout, Input, Concatenate, LeakyReLU, BatchNormalization, Activation
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import minmax_scale
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from google.colab import files
from numpy import savetxt
from keras.layers import Layer
from xgboost import XGBRegressor
from matplotlib import pyplot
np.random.seed(30)
tf.random.set_seed(30)

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Physics_Guided_WA_L1_Regularizer/Input_Output_Data_XPG_L1_Reg.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten().round(2),'SS':data1['SS'].flatten()})
df = df[['F1','SS']]

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

# %%
## Define DD
def MLP_Data():

    # Define inputs
    X_train = layers.Input(shape=(n_steps,),name='X_train')

    # Prediction: Shear Stress + Slip Rate
    x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
    x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
    x = layers.Dense(32,kernel_initializer = 'normal', activation="relu")(x)
    x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
    x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
    ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

    model = keras.Model(inputs=[X_train],outputs=[ss_pred])
    return model

# %%
model = MLP_Data()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,537 (193.50 KB)
#  Trainable params: 49,537 (193.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile & Run
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])

earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
plt.figure()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2157/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1370 - mse: 4.1370
# Epoch 1: val_loss improved from inf to 0.00344, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.1040 - mse: 4.1040 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 2/100
# 2171/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 2: val_loss improved from 0.00344 to 0.00234, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 3/100
# 2160/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 3: val_loss improved from 0.00234 to 0.00201, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 4/100
# 2170/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 4: val_loss did not improve from 0.00201
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 5/100
# 2167/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 5: val_loss improved from 0.00201 to 0.00194, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 6/100
# 2158/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 6: val_loss improved from 0.00194 to 0.00188, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 7/100
# 2169/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 7: val_loss improved from 0.00188 to 0.00184, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 8/100
# 2161/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 8: val_loss improved from 0.00184 to 0.00184, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 9/100
# 2169/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 9: val_loss did not improve from 0.00184
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 10/100
# 2180/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 10: val_loss did not improve from 0.00184
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 11/100
# 2175/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 11: val_loss did not improve from 0.00184
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 12/100
# 2178/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 12: val_loss did not improve from 0.00184
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 13/100
# 2159/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 13: val_loss improved from 0.00184 to 0.00182, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 14/100
# 2170/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 14: val_loss did not improve from 0.00182
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 15/100
# 2173/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 15: val_loss did not improve from 0.00182
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 16/100
# 2161/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 16: val_loss did not improve from 0.00182
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 17/100
# 2170/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 17: val_loss did not improve from 0.00182
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 18/100
# 2172/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 18: val_loss did not improve from 0.00182
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 19/100
# 2172/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 19: val_loss did not improve from 0.00182
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 20/100
# 2180/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 20: val_loss improved from 0.00182 to 0.00171, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 21/100
# 2166/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 21: val_loss improved from 0.00171 to 0.00099, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 9.9477e-04 - val_mse: 9.9477e-04
# Epoch 22/100
# 2159/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 22: val_loss improved from 0.00099 to 0.00092, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 9.2290e-04 - val_mse: 9.2290e-04
# Epoch 23/100
# 2178/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 23: val_loss improved from 0.00092 to 0.00092, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 9.2022e-04 - val_mse: 9.2022e-04
# Epoch 24/100
# 2174/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 24: val_loss did not improve from 0.00092
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 9.4145e-04 - val_mse: 9.4145e-04
# Epoch 25/100
# 2167/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 25: val_loss did not improve from 0.00092
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 9.6446e-04 - val_mse: 9.6446e-04
# Epoch 26/100
# 2176/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 26: val_loss improved from 0.00092 to 0.00085, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 8.4969e-04 - val_mse: 8.4969e-04
# Epoch 27/100
# 2159/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 27: val_loss improved from 0.00085 to 0.00085, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 8.4750e-04 - val_mse: 8.4750e-04
# Epoch 28/100
# 2158/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 28: val_loss improved from 0.00085 to 0.00083, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 8.2798e-04 - val_mse: 8.2798e-04
# Epoch 29/100
# 2174/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 29: val_loss improved from 0.00083 to 0.00078, saving model to /content/drive/My Drive/Colab Notebooks/p5270/Automatic_Physics_Based_Features_Extraction/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 7.8073e-04 - val_mse: 7.8073e-04
# Epoch 30/100
# 2176/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 30: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 7.8414e-04 - val_mse: 7.8414e-04
# Epoch 31/100
# 2176/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 31: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 8.7101e-04 - val_mse: 8.7101e-04
# Epoch 32/100
# 2167/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 32: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 8.6309e-04 - val_mse: 8.6309e-04
# Epoch 33/100
# 2165/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 33: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.4427e-04 - val_mse: 8.4427e-04
# Epoch 34/100
# 2166/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 34: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.4262e-04 - val_mse: 8.4262e-04
# Epoch 35/100
# 2175/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 35: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.5823e-04 - val_mse: 8.5823e-04
# Epoch 36/100
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 36: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.7468e-04 - val_mse: 8.7468e-04
# Epoch 37/100
# 2157/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 37: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.4035e-04 - val_mse: 8.4035e-04
# Epoch 38/100
# 2159/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 38: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.6747e-04 - val_mse: 8.6747e-04
# Epoch 39/100
# 2169/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 39: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.7514e-04 - val_mse: 8.7514e-04
# Epoch 40/100
# 2172/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 40: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 9.1137e-04 - val_mse: 9.1137e-04
# Epoch 41/100
# 2161/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 41: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.7522e-04 - val_mse: 8.7522e-04
# Epoch 42/100
# 2155/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 42: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.8491e-04 - val_mse: 8.8491e-04
# Epoch 43/100
# 2170/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 43: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.9257e-04 - val_mse: 8.9257e-04
# Epoch 44/100
# 2169/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 44: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 9.0667e-04 - val_mse: 9.0667e-04
# Epoch 45/100
# 2177/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 45: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 9.5080e-04 - val_mse: 9.5080e-04
# Epoch 46/100
# 2179/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 46: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 9.3464e-04 - val_mse: 9.3464e-04
# Epoch 47/100
# 2174/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 47: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 9.1517e-04 - val_mse: 9.1517e-04
# Epoch 48/100
# 2172/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 48: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 9.6639e-04 - val_mse: 9.6639e-04
# Epoch 49/100
# 2165/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 49: val_loss did not improve from 0.00078
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 9.9470e-04 - val_mse: 9.9470e-04
# Epoch 49: early stopping

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train],verbose=0)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

  # Model Performance: Validation
y_predval = model.predict([X_val],verbose=0)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

  # Model Performance: Testing
y_predtest = model.predict([x_test],verbose=0)
y_predtest_SS = np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS, y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

  # Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

  # Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# R2 scores: Train (SS) - 0.90794
# R2 scores: Validation (SS) - 0.94119
# R2 scores: Testing (SS) - 0.93770
# RMSE scores: Train (SS) - 0.03732
# RMSE scores: Validation (SS) - 0.03154
# RMSE scores: Testing (SS) - 0.03558

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
