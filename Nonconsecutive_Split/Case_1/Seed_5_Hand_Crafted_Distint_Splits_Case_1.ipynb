# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(40)
tf.random.set_seed(40)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270_Data.mat')
data2 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270MechData.mat')
a_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2), 'freqQAmpI_filt':data1['freqQAmpI_filt'].ravel()})
w_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2),'C_filt':data1['C_filt'].ravel()})
m_t = pd.DataFrame({'Time':data1['Time'].ravel().round(2), 'SS':data1['SS'].ravel()})
s_t = pd.DataFrame({'Time':data2['Time'].ravel().round(2), 'V':data2['V'].ravel(),'V_filt':data2['V_filt'].ravel()})
df = a_t.merge(w_t, on='Time')
df = df.merge(m_t, on='Time')
df = df.merge(s_t, on='Time')
df = df[['freqQAmpI_filt','Time','SS']]
df_SS = df[['freqQAmpI_filt','SS']]
df_A = df[['freqQAmpI_filt','freqQAmpI_filt']]
xdf = df[['freqQAmpI_filt']]
ydf = df[['SS']]

print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#          freqQAmpI_filt
# 0         31453.223522
# 1         31438.277060
# 2         31421.341616
# 3         31409.798761
# 4         31398.815589
# ...                ...
# 132394    31055.686766
# 132395    31041.955345
# 132396    31035.059531
# 132397    31020.001291
# 132398    31012.016780
#
# [132399 rows x 1 columns]
# Target Data:
#                SS
# 0       5.656166
# 1       5.657157
# 2       5.658317
# 3       5.659499
# 4       5.660404
# ...          ...
# 132394  5.471059
# 132395  5.474545
# 132396  5.478286
# 132397  5.481751
# 132398  5.484813
#
# [132399 rows x 1 columns]

# %%
# Split into train-val-test (SS)
x_train_full, x_test_full, y_train_SS_full, y_test_SS_full = train_test_split(xdf, ydf, test_size=0.2, shuffle=False)
X_train_initial, X_val_initial, Y_train_SS_initial, Y_val_SS_initial = train_test_split(x_train_full, y_train_SS_full, test_size=0.125, shuffle=False)

# Select the training data (inputs & outputs) and capture original indices
sp_train = 0
ep_train = 80000
X_train = X_train_initial.iloc[sp_train:ep_train]
Y_train_SS = Y_train_SS_initial.iloc[sp_train:ep_train]
Y_train_SS_time_indices = Y_train_SS.index

# Select the validation data (inputs & outputs) and capture original indices
sp_val = 0
ep_val = 9000
X_val = X_val_initial.iloc[sp_val:ep_val]
Y_val_SS = Y_val_SS_initial.iloc[sp_val:ep_val]
Y_val_SS_time_indices = Y_val_SS.index

# Select the test data (inputs & outputs) and capture original indices
sp_test = 5000
ep_test = 26480 # 26480
x_test = x_test_full.iloc[sp_test:ep_test]
y_test_SS = y_test_SS_full.iloc[sp_test:ep_test]
y_test_SS_time_indices = y_test_SS.index


print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 80000
# Validation samples: 9000
# Testing samples: 21480

# %%
# Plot data
plt.figure(figsize=(18, 4))
plt.plot(df['Time'], df['SS'], label='Actual', color='black', alpha=0.7)
plt.plot(df['Time'].loc[Y_train_SS.index], Y_train_SS, label='Training', color='blue')
plt.plot(df['Time'].loc[Y_val_SS.index], Y_val_SS, label='Validation', color='green')
plt.plot(df['Time'].loc[y_test_SS.index], y_test_SS, label='Testing', color='red')
plt.xlabel('Time (s)')
plt.ylabel('Shear Stress (MPa)')
# plt.title('Data Splits Over Time')
plt.legend()
plt.show()

# %%
# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

# %%
# Normalize the output
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS))

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Pre process training
combined_train_data = pd.concat([X_train, Y_train_SS], axis=1)
arr_train = combined_train_data.to_numpy()
n_steps = 300
X_train, Y_train_SS = create_timesteps(arr_train, n_steps)

in_dim = X_train.shape[1]*X_train.shape[2]
X_train = X_train.reshape((X_train.shape[0], in_dim))
print('Training Input Shape, X = ', np.shape(X_train))

print('Training Output Shape, Y = ', np.shape(Y_train_SS))
# Out:
# Training Input Shape, X =  (79700, 300)
# Training Output Shape, Y =  (79700,)

# %%
# Pre process validation
combined_val_data = pd.concat([X_val, Y_val_SS], axis=1)
arr_val = combined_val_data.to_numpy()
n_steps = 300
X_val, Y_val_SS = create_timesteps(arr_val, n_steps)

in_dim = X_val.shape[1]*X_val.shape[2]
X_val = X_val.reshape((X_val.shape[0], in_dim))
print('Validation Input Shape, X = ', np.shape(X_val))

print('Validation Output Shape, Y = ', np.shape(Y_val_SS))
# Out:
# Validation Input Shape, X =  (8700, 300)
# Validation Output Shape, Y =  (8700,)

# %%
# Pre process testing
combined_test_data = pd.concat([x_test, y_test_SS], axis=1)
arr_test = combined_test_data.to_numpy()
n_steps = 300
x_test, y_test_SS = create_timesteps(arr_test, n_steps)

in_dim = x_test.shape[1]*x_test.shape[2]
x_test = x_test.reshape((x_test.shape[0], in_dim))
print('Testing Input Shape, X = ', np.shape(x_test))

print('Testing Output Shape, Y = ', np.shape(y_test_SS))
# Out:
# Testing Input Shape, X =  (21180, 300)
# Testing Output Shape, Y =  (21180,)

# %% [markdown]
# **Define Data-Driven Model**

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer= tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,537 (193.50 KB)
#  Trainable params: 49,537 (193.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2479/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0778 - mse: 0.0778
# Epoch 1: val_loss improved from None to 0.02114, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0211 - val_mse: 0.0211
# Epoch 2/100
# 2476/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0134 - mse: 0.0134
# Epoch 2: val_loss improved from 0.02114 to 0.01529, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 3/100
# 2487/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075 - mse: 0.0075
# Epoch 3: val_loss improved from 0.01529 to 0.00789, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 4/100
# 2486/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mse: 0.0052
# Epoch 4: val_loss improved from 0.00789 to 0.00788, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 5/100
# 2485/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - mse: 0.0040
# Epoch 5: val_loss improved from 0.00788 to 0.00758, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 6/100
# 2487/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mse: 0.0038
# Epoch 6: val_loss did not improve from 0.00758
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 7/100
# 2490/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 7: val_loss improved from 0.00758 to 0.00711, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 8/100
# 2478/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 8: val_loss did not improve from 0.00711
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 9/100
# 2489/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 9: val_loss improved from 0.00711 to 0.00696, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 10/100
# 2490/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 10: val_loss did not improve from 0.00696
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 11/100
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 11: val_loss did not improve from 0.00696
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 12/100
# 2486/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 12: val_loss did not improve from 0.00696
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 13/100
# 2477/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 13: val_loss did not improve from 0.00696
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 14/100
# 2489/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 14: val_loss did not improve from 0.00696
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 15/100
# 2489/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 15: val_loss did not improve from 0.00696
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 16/100
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 16: val_loss did not improve from 0.00696
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 17/100
# 2486/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 17: val_loss improved from 0.00696 to 0.00659, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 17: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 18/100
# 2480/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 18: val_loss did not improve from 0.00659
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 19/100
# 2484/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 19: val_loss did not improve from 0.00659
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 20/100
# 2477/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 20: val_loss did not improve from 0.00659
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 21/100
# 2473/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 21: val_loss did not improve from 0.00659
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 22/100
# 2488/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 22: val_loss improved from 0.00659 to 0.00649, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 22: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 23/100
# 2486/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 23: val_loss did not improve from 0.00649
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 24/100
# 2485/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 24: val_loss did not improve from 0.00649
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 25/100
# 2489/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 25: val_loss did not improve from 0.00649
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 26/100
# 2490/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 26: val_loss did not improve from 0.00649
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 27/100
# 2480/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 27: val_loss did not improve from 0.00649
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 28/100
# 2484/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 28: val_loss improved from 0.00649 to 0.00595, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 28: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 29/100
# 2478/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 29: val_loss did not improve from 0.00595
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 30/100
# 2486/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 30: val_loss did not improve from 0.00595
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 31/100
# 2480/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 31: val_loss did not improve from 0.00595
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 32/100
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 32: val_loss did not improve from 0.00595
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 33/100
# 2490/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 33: val_loss did not improve from 0.00595
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 34/100
# 2476/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 34: val_loss did not improve from 0.00595
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 35/100
# 2480/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 35: val_loss improved from 0.00595 to 0.00585, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 35: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 36/100
# 2479/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 36: val_loss did not improve from 0.00585
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 37/100
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 37: val_loss did not improve from 0.00585
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 38/100
# 2489/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 38: val_loss improved from 0.00585 to 0.00507, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 38: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 39/100
# 2481/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 39: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 40/100
# 2483/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 40: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 41/100
# 2473/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 41: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 42/100
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 42: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 43/100
# 2490/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 43: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 44/100
# 2485/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 44: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 45/100
# 2485/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 45: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 46/100
# 2482/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 46: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 47/100
# 2480/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 47: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 48/100
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 48: val_loss did not improve from 0.00507
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 49/100
# 2485/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 49: val_loss improved from 0.00507 to 0.00483, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 49: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 50/100
# 2472/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 50: val_loss did not improve from 0.00483
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 51/100
# 2488/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 51: val_loss did not improve from 0.00483
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 52/100
# 2486/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 52: val_loss did not improve from 0.00483
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 53/100
# 2484/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 53: val_loss did not improve from 0.00483
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 54/100
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 54: val_loss improved from 0.00483 to 0.00481, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 54: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 55/100
# 2482/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 55: val_loss did not improve from 0.00481
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 56/100
# 2488/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 56: val_loss did not improve from 0.00481
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 57/100
# 2488/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 57: val_loss improved from 0.00481 to 0.00469, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 57: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 58/100
# 2480/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 58: val_loss did not improve from 0.00469
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 59/100
# 2485/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 59: val_loss improved from 0.00469 to 0.00370, saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
#
# Epoch 59: finished saving model to /content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/Nonconsecutive_Splits/Hand_Crafted_Model/Case_1/Check/Check_40.keras
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 60/100
# 2482/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 60: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 61/100
# 2490/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 61: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 62/100
# 2487/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 62: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 63/100
# 2489/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 63: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 64/100
# 2477/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 64: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 65/100
# 2480/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 65: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 66/100
# 2480/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 66: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 67/100
# 2489/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 67: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 68/100
# 2477/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 68: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 69/100
# 2481/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 69: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 70/100
# 2482/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 70: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 71/100
# 2483/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 71: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 72/100
# 2480/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 72: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 73/100
# 2490/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 73: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 74/100
# 2484/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 74: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 75/100
# 2474/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 75: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 76/100
# 2488/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 76: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 77/100
# 2484/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 77: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 78/100
# 2484/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 78: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 79/100
# 2484/2491 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 79: val_loss did not improve from 0.00370
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 79: early stopping
# ---Training time: 825.29107308 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train])
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict([X_val])
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict([x_test])
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))
# Out:
# 2491/2491 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 662/662 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# R2 scores: Train (SS) - 0.95650
# R2 scores: Validation (SS) - 0.88249
# R2 scores: Testing (SS) - 0.82236

# %%
# Overall plots

# Denormalize the predictions
y_predtrain_SS_denorm = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS_denorm = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS_denorm = scaler_ss.inverse_transform(y_predtest_SS)

# Get the actual time indices for the predictions, accounting for n_steps
traintime = df['Time'].loc[Y_train_SS_time_indices[n_steps:]]
valtime = df['Time'].loc[Y_val_SS_time_indices[n_steps:]]
testtime = df['Time'].loc[y_test_SS_time_indices[n_steps:]]

## SS
fig = plt.figure(1, figsize=(20,6))
plt.plot(df['Time'], df['SS'], label='Ground truth') # Plot entire original data as ground truth
plt.plot(traintime, y_predtrain_SS_denorm, label='Train Prediction')
plt.plot(valtime, y_predval_SS_denorm, label='Val Prediction')
plt.plot(testtime, y_predtest_SS_denorm, label='Test Prediction')
plt.xlabel('Time (s)')
plt.ylabel('Shear Stress (MPa)')
# plt.text(df['Time'].iloc[0], 5.3, f'Test R2 Score: {test_r2_SS:.5f}', style='italic', bbox=dict(facecolor='red', alpha=0.5, pad=10))
plt.legend()
# plt.title('Shear Stress Prediction')
