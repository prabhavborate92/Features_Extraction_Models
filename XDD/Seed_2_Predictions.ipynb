# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(10)
tf.random.set_seed(10)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Input_Output_Data_5_Features.mat')
df = pd.DataFrame({'F1':data1['F1'].ravel().round(2), 'F2':data1['F2'].ravel().round(2) ,'F3':data1['F3'].ravel().round(2),'F4':data1['F4'].ravel().round(2),
                   'F5':data1['F5'].ravel().round(2), 'SS':data1['SS_Final'].ravel()})
df = df[['F1','F2','F3','F4','F5','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132105, 300, 5)
# Target shape (SS), Y =  (132105,)
# After reshaping, X =  (132105, 1500)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92473, 1500)
# Validation samples: (13211, 1500)
# Testing samples: (26421, 1500)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(1500),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.legacy.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  X_train (InputLayer)        [(None, 1500)]            0
#
#  dense (Dense)               (None, 512)               768512
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 838337 (3.20 MB)
# Trainable params: 838337 (3.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 92473 samples, validate on 13211 samples
# Epoch 1/100
# 92473/92473 [==============================] - ETA: 0s - loss: 0.0101 - mse: 0.0101
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 1: val_loss improved from inf to 0.00604, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check
# 92473/92473 [==============================] - 33s 360us/sample - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 2/100
# 92384/92473 [============================>.] - ETA: 0s - loss: 0.0037 - mse: 0.0037
# Epoch 2: val_loss improved from 0.00604 to 0.00472, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check
# 92473/92473 [==============================] - 33s 359us/sample - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 3/100
# 92352/92473 [============================>.] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 3: val_loss did not improve from 0.00472
# 92473/92473 [==============================] - 33s 358us/sample - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 4/100
# 92448/92473 [============================>.] - ETA: 0s - loss: 0.0024 - mse: 0.0024
# Epoch 4: val_loss improved from 0.00472 to 0.00343, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check
# 92473/92473 [==============================] - 32s 345us/sample - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 5/100
# 92320/92473 [============================>.] - ETA: 0s - loss: 0.0021 - mse: 0.0021
# Epoch 5: val_loss improved from 0.00343 to 0.00232, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check
# 92473/92473 [==============================] - 33s 355us/sample - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 6/100
# 92448/92473 [============================>.] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 6: val_loss did not improve from 0.00232
# 92473/92473 [==============================] - 32s 341us/sample - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 7/100
# 92416/92473 [============================>.] - ETA: 0s - loss: 0.0017 - mse: 0.0017
# Epoch 7: val_loss did not improve from 0.00232
# 92473/92473 [==============================] - 31s 337us/sample - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 8/100
# 92473/92473 [==============================] - ETA: 0s - loss: 0.0016 - mse: 0.0016
# Epoch 8: val_loss improved from 0.00232 to 0.00218, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check
# 92473/92473 [==============================] - 33s 355us/sample - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 9/100
# 92416/92473 [============================>.] - ETA: 0s - loss: 0.0016 - mse: 0.0016
# Epoch 9: val_loss did not improve from 0.00218
# 92473/92473 [==============================] - 31s 341us/sample - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 10/100
# 92352/92473 [============================>.] - ETA: 0s - loss: 0.0014 - mse: 0.0014
# Epoch 10: val_loss did not improve from 0.00218
# 92473/92473 [==============================] - 31s 335us/sample - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 11/100
# 92384/92473 [============================>.] - ETA: 0s - loss: 0.0014 - mse: 0.0014
# Epoch 11: val_loss did not improve from 0.00218
# 92473/92473 [==============================] - 31s 336us/sample - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 12/100
# 92352/92473 [============================>.] - ETA: 0s - loss: 0.0013 - mse: 0.0013
# Epoch 12: val_loss did not improve from 0.00218
# 92473/92473 [==============================] - 31s 332us/sample - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 13/100
# 92448/92473 [============================>.] - ETA: 0s - loss: 0.0013 - mse: 0.0013
# Epoch 13: val_loss did not improve from 0.00218
# 92473/92473 [==============================] - 32s 348us/sample - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 14/100
# 92473/92473 [==============================] - ETA: 0s - loss: 0.0012 - mse: 0.0012
# Epoch 14: val_loss improved from 0.00218 to 0.00196, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check
# 92473/92473 [==============================] - 33s 356us/sample - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 15/100
# 92416/92473 [============================>.] - ETA: 0s - loss: 0.0012 - mse: 0.0012
# Epoch 15: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 32s 344us/sample - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 16/100
# 92416/92473 [============================>.] - ETA: 0s - loss: 0.0012 - mse: 0.0012
# Epoch 16: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 339us/sample - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 17/100
# 92384/92473 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 0.0011
# Epoch 17: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 32s 342us/sample - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 18/100
# 92352/92473 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 0.0011
# Epoch 18: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 337us/sample - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 19/100
# 92352/92473 [============================>.] - ETA: 0s - loss: 0.0010 - mse: 0.0010
# Epoch 19: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 334us/sample - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 20/100
# 92416/92473 [============================>.] - ETA: 0s - loss: 0.0010 - mse: 0.0010
# Epoch 20: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 33s 356us/sample - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 21/100
# 92384/92473 [============================>.] - ETA: 0s - loss: 9.7302e-04 - mse: 9.7302e-04
# Epoch 21: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 336us/sample - loss: 9.7305e-04 - mse: 9.7305e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 22/100
# 92352/92473 [============================>.] - ETA: 0s - loss: 0.0010 - mse: 0.0010
# Epoch 22: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 333us/sample - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 23/100
# 92416/92473 [============================>.] - ETA: 0s - loss: 8.9846e-04 - mse: 8.9847e-04
# Epoch 23: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 30s 330us/sample - loss: 8.9829e-04 - mse: 8.9829e-04 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 24/100
# 92448/92473 [============================>.] - ETA: 0s - loss: 9.0188e-04 - mse: 9.0188e-04
# Epoch 24: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 334us/sample - loss: 9.0187e-04 - mse: 9.0187e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 25/100
# 92416/92473 [============================>.] - ETA: 0s - loss: 9.2246e-04 - mse: 9.2246e-04
# Epoch 25: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 332us/sample - loss: 9.2254e-04 - mse: 9.2254e-04 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 26/100
# 92384/92473 [============================>.] - ETA: 0s - loss: 8.8121e-04 - mse: 8.8121e-04
# Epoch 26: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 334us/sample - loss: 8.8079e-04 - mse: 8.8079e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 27/100
# 92320/92473 [============================>.] - ETA: 0s - loss: 8.5973e-04 - mse: 8.5973e-04
# Epoch 27: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 30s 328us/sample - loss: 8.6041e-04 - mse: 8.6041e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 28/100
# 92384/92473 [============================>.] - ETA: 0s - loss: 8.2319e-04 - mse: 8.2319e-04
# Epoch 28: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 337us/sample - loss: 8.2311e-04 - mse: 8.2311e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 29/100
# 92320/92473 [============================>.] - ETA: 0s - loss: 8.2081e-04 - mse: 8.2081e-04
# Epoch 29: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 333us/sample - loss: 8.2229e-04 - mse: 8.2229e-04 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 30/100
# 92320/92473 [============================>.] - ETA: 0s - loss: 7.9696e-04 - mse: 7.9696e-04
# Epoch 30: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 335us/sample - loss: 8.0206e-04 - mse: 8.0206e-04 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 31/100
# 92473/92473 [==============================] - ETA: 0s - loss: 7.9892e-04 - mse: 7.9892e-04
# Epoch 31: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 331us/sample - loss: 7.9892e-04 - mse: 7.9892e-04 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 32/100
# 92384/92473 [============================>.] - ETA: 0s - loss: 8.0318e-04 - mse: 8.0318e-04
# Epoch 32: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 339us/sample - loss: 8.0283e-04 - mse: 8.0282e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 33/100
# 92448/92473 [============================>.] - ETA: 0s - loss: 7.3692e-04 - mse: 7.3692e-04
# Epoch 33: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 335us/sample - loss: 7.3686e-04 - mse: 7.3686e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 34/100
# 92384/92473 [============================>.] - ETA: 0s - loss: 7.5450e-04 - mse: 7.5450e-04
# Epoch 34: val_loss did not improve from 0.00196
# 92473/92473 [==============================] - 31s 335us/sample - loss: 7.5449e-04 - mse: 7.5449e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 34: early stopping
# ---Training time: 1071.72109818 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# R2 scores: Train (SS) - 0.96501
# R2 scores: Validation (SS) - 0.89788
# R2 scores: Testing (SS) - 0.74985
# RMSE scores: Train (SS) - 0.03122
# RMSE scores: Validation (SS) - 0.06140
# RMSE scores: Testing (SS) - 0.09420
