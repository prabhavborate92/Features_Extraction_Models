# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Features_Comparison_Model/Reviewer_1_Suggestion_CNN/CNN/Hyperparameter_Tuning/Model_6/Input_Output_Data_Model_6.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten() ,'F3':data1['F3'].flatten(),'F4':data1['F4'].flatten(),
                   'F5':data1['F5'].flatten(), 'F6':data1['F6'].flatten(), 'F7':data1['F7'].flatten(), 'F8':data1['F8'].flatten(),
                   'F9':data1['F9'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1','F2','F3','F4','F5','F6','F7','F8','F9','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 9)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 2700)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 2700)
# Validation samples: (13208, 2700)
# Testing samples: (26416, 2700)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(2700,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(2048,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(128, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 2700)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2048)           │     5,531,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,646,529 (25.35 MB)
#  Trainable params: 6,646,529 (25.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.2687 - mse: 0.2687
# Epoch 1: val_loss improved from inf to 0.02620, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 300s 103ms/step - loss: 0.2686 - mse: 0.2686 - val_loss: 0.0262 - val_mse: 0.0262
# Epoch 2/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 2: val_loss improved from 0.02620 to 0.02584, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 324s 103ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0258 - val_mse: 0.0258
# Epoch 3/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 3: val_loss did not improve from 0.02584
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 324s 104ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0262 - val_mse: 0.0262
# Epoch 4/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 4: val_loss improved from 0.02584 to 0.01850, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 315s 102ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 5/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 5: val_loss did not improve from 0.01850
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 320s 101ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 6/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 6: val_loss did not improve from 0.01850
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 316s 99ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 7/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 7: val_loss improved from 0.01850 to 0.01669, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 351s 109ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 8/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 8: val_loss improved from 0.01669 to 0.01421, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 302s 104ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 9/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 9: val_loss did not improve from 0.01421
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 318s 110ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 10/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 10: val_loss did not improve from 0.01421
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 296s 101ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 11/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 11: val_loss improved from 0.01421 to 0.01416, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 344s 109ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 12/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 9.4042e-04 - mse: 9.4042e-04
# Epoch 12: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 341s 115ms/step - loss: 9.4040e-04 - mse: 9.4040e-04 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 13/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 8.8462e-04 - mse: 8.8462e-04
# Epoch 13: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 376s 113ms/step - loss: 8.8460e-04 - mse: 8.8460e-04 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 14/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 8.4328e-04 - mse: 8.4328e-04
# Epoch 14: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 354s 104ms/step - loss: 8.4326e-04 - mse: 8.4326e-04 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 15/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 7.8806e-04 - mse: 7.8806e-04
# Epoch 15: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 320s 103ms/step - loss: 7.8805e-04 - mse: 7.8805e-04 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 16/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 7.5957e-04 - mse: 7.5957e-04
# Epoch 16: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 301s 104ms/step - loss: 7.5955e-04 - mse: 7.5955e-04 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 17/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 7.2201e-04 - mse: 7.2201e-04
# Epoch 17: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 316s 109ms/step - loss: 7.2199e-04 - mse: 7.2199e-04 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 18/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 6.9935e-04 - mse: 6.9935e-04
# Epoch 18: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 327s 113ms/step - loss: 6.9934e-04 - mse: 6.9934e-04 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 19/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 6.8173e-04 - mse: 6.8173e-04
# Epoch 19: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 349s 102ms/step - loss: 6.8172e-04 - mse: 6.8172e-04 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 20/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 6.2543e-04 - mse: 6.2543e-04
# Epoch 20: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 343s 119ms/step - loss: 6.2543e-04 - mse: 6.2543e-04 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 21/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 6.3062e-04 - mse: 6.3062e-04
# Epoch 21: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 333s 115ms/step - loss: 6.3061e-04 - mse: 6.3061e-04 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 22/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 6.2244e-04 - mse: 6.2244e-04
# Epoch 22: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 381s 115ms/step - loss: 6.2243e-04 - mse: 6.2243e-04 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 23/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 5.9434e-04 - mse: 5.9434e-04
# Epoch 23: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 357s 106ms/step - loss: 5.9434e-04 - mse: 5.9434e-04 - val_loss: 0.0202 - val_mse: 0.0202
# Epoch 24/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 5.8874e-04 - mse: 5.8874e-04
# Epoch 24: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 315s 104ms/step - loss: 5.8873e-04 - mse: 5.8873e-04 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 25/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 5.6911e-04 - mse: 5.6911e-04
# Epoch 25: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 293s 102ms/step - loss: 5.6910e-04 - mse: 5.6910e-04 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 26/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 5.5121e-04 - mse: 5.5121e-04
# Epoch 26: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 296s 102ms/step - loss: 5.5121e-04 - mse: 5.5121e-04 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 27/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 5.5972e-04 - mse: 5.5972e-04
# Epoch 27: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 326s 104ms/step - loss: 5.5971e-04 - mse: 5.5971e-04 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 28/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 5.3739e-04 - mse: 5.3739e-04
# Epoch 28: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 293s 101ms/step - loss: 5.3738e-04 - mse: 5.3738e-04 - val_loss: 0.0172 - val_mse: 0.0172
# Epoch 29/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 5.0803e-04 - mse: 5.0803e-04
# Epoch 29: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 334s 106ms/step - loss: 5.0803e-04 - mse: 5.0803e-04 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 30/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 5.2928e-04 - mse: 5.2928e-04
# Epoch 30: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 337s 111ms/step - loss: 5.2928e-04 - mse: 5.2928e-04 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 31/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 5.0040e-04 - mse: 5.0040e-04
# Epoch 31: val_loss did not improve from 0.01416
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 302s 104ms/step - loss: 5.0040e-04 - mse: 5.0040e-04 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 31: early stopping
# ---Training time: 10107.12087440 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
#    3/2890 ━━━━━━━━━━━━━━━━━━━━ 1:14 26ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(32, 2700))
#   warnings.warn(msg)
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 62s 21ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(None, 2700))
#   warnings.warn(msg)
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step
# R2 scores: Train (SS) - 0.97932
# R2 scores: Validation (SS) - 0.59984
# R2 scores: Testing (SS) - 0.04095
# RMSE scores: Train (SS) - 0.02345
# RMSE scores: Validation (SS) - 0.11902
# RMSE scores: Testing (SS) - 0.18050

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
