# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Features_Comparison_Model/Reviewer_1_Suggestion_CNN/CNN/Hyperparameter_Tuning/Model_2/Input_Output_Data_Model_2.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten() ,'F3':data1['F3'].flatten(),'F4':data1['F4'].flatten(),
                   'F5':data1['F5'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1','F2','F3','F4','F5','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 5)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 1500)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 1500)
# Validation samples: (13208, 1500)
# Testing samples: (26416, 1500)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(1500,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(X_train)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 1500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       768,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 769,025 (2.93 MB)
#  Trainable params: 769,025 (2.93 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2954 - mse: 0.2954
# Epoch 1: val_loss improved from inf to 0.00979, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 36s 12ms/step - loss: 0.2950 - mse: 0.2950 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 2/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 2: val_loss did not improve from 0.00979
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 3/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 3: val_loss did not improve from 0.00979
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 34s 12ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 4/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 4: val_loss did not improve from 0.00979
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 34s 12ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 5/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 5: val_loss improved from 0.00979 to 0.00871, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 35s 12ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 6/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.9651e-04 - mse: 9.9651e-04
# Epoch 6: val_loss improved from 0.00871 to 0.00716, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 33s 11ms/step - loss: 9.9652e-04 - mse: 9.9652e-04 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 7/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2648e-04 - mse: 9.2648e-04
# Epoch 7: val_loss improved from 0.00716 to 0.00618, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 33s 11ms/step - loss: 9.2648e-04 - mse: 9.2648e-04 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 8/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.8417e-04 - mse: 8.8417e-04
# Epoch 8: val_loss improved from 0.00618 to 0.00568, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 35s 12ms/step - loss: 8.8419e-04 - mse: 8.8419e-04 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 9/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.4882e-04 - mse: 8.4882e-04
# Epoch 9: val_loss improved from 0.00568 to 0.00543, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - loss: 8.4883e-04 - mse: 8.4883e-04 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 10/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.2233e-04 - mse: 8.2233e-04
# Epoch 10: val_loss improved from 0.00543 to 0.00508, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 34s 12ms/step - loss: 8.2233e-04 - mse: 8.2233e-04 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 11/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1136e-04 - mse: 8.1136e-04
# Epoch 11: val_loss improved from 0.00508 to 0.00486, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 12ms/step - loss: 8.1138e-04 - mse: 8.1138e-04 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 12/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.9597e-04 - mse: 7.9597e-04
# Epoch 12: val_loss improved from 0.00486 to 0.00476, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 35s 12ms/step - loss: 7.9598e-04 - mse: 7.9598e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 13/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.9024e-04 - mse: 7.9024e-04
# Epoch 13: val_loss improved from 0.00476 to 0.00472, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 43s 13ms/step - loss: 7.9024e-04 - mse: 7.9024e-04 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 14/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8383e-04 - mse: 7.8383e-04
# Epoch 14: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 36s 12ms/step - loss: 7.8382e-04 - mse: 7.8382e-04 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 15/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.7477e-04 - mse: 7.7477e-04
# Epoch 15: val_loss improved from 0.00472 to 0.00472, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 37s 13ms/step - loss: 7.7477e-04 - mse: 7.7477e-04 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 16/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6502e-04 - mse: 7.6502e-04
# Epoch 16: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - loss: 7.6502e-04 - mse: 7.6502e-04 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 17/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5835e-04 - mse: 7.5835e-04
# Epoch 17: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 36s 13ms/step - loss: 7.5835e-04 - mse: 7.5835e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 18/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5154e-04 - mse: 7.5154e-04
# Epoch 18: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 36s 13ms/step - loss: 7.5154e-04 - mse: 7.5154e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 19/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.4889e-04 - mse: 7.4889e-04
# Epoch 19: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 35s 12ms/step - loss: 7.4888e-04 - mse: 7.4888e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 20/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.4197e-04 - mse: 7.4197e-04
# Epoch 20: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 37s 13ms/step - loss: 7.4196e-04 - mse: 7.4196e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 21/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3729e-04 - mse: 7.3729e-04
# Epoch 21: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - loss: 7.3729e-04 - mse: 7.3729e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 22/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3221e-04 - mse: 7.3221e-04
# Epoch 22: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - loss: 7.3220e-04 - mse: 7.3220e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 23/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2964e-04 - mse: 7.2964e-04
# Epoch 23: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 7.2963e-04 - mse: 7.2963e-04 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 24/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2093e-04 - mse: 7.2093e-04
# Epoch 24: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - loss: 7.2092e-04 - mse: 7.2092e-04 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 25/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1724e-04 - mse: 7.1724e-04
# Epoch 25: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - loss: 7.1724e-04 - mse: 7.1724e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 26/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.1425e-04 - mse: 7.1425e-04
# Epoch 26: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - loss: 7.1425e-04 - mse: 7.1425e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 27/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0828e-04 - mse: 7.0828e-04
# Epoch 27: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 34s 12ms/step - loss: 7.0828e-04 - mse: 7.0828e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 28/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0577e-04 - mse: 7.0577e-04
# Epoch 28: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 35s 12ms/step - loss: 7.0577e-04 - mse: 7.0577e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 29/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0133e-04 - mse: 7.0133e-04
# Epoch 29: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 37s 13ms/step - loss: 7.0133e-04 - mse: 7.0133e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 30/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9768e-04 - mse: 6.9768e-04
# Epoch 30: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 36s 12ms/step - loss: 6.9768e-04 - mse: 6.9768e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 31/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9446e-04 - mse: 6.9446e-04
# Epoch 31: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 34s 12ms/step - loss: 6.9446e-04 - mse: 6.9446e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 32/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9136e-04 - mse: 6.9136e-04
# Epoch 32: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - loss: 6.9136e-04 - mse: 6.9136e-04 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 33/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.8717e-04 - mse: 6.8717e-04
# Epoch 33: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 36s 12ms/step - loss: 6.8717e-04 - mse: 6.8717e-04 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 34/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.8542e-04 - mse: 6.8542e-04
# Epoch 34: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - loss: 6.8542e-04 - mse: 6.8542e-04 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 35/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.8186e-04 - mse: 6.8186e-04
# Epoch 35: val_loss did not improve from 0.00472
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 36s 12ms/step - loss: 6.8186e-04 - mse: 6.8186e-04 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 35: early stopping
# ---Training time: 1307.92878604 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
#   52/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(32, 1500))
#   warnings.warn(msg)
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(None, 1500))
#   warnings.warn(msg)
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# R2 scores: Train (SS) - 0.94329
# R2 scores: Validation (SS) - 0.86119
# R2 scores: Testing (SS) - 0.58931
# RMSE scores: Train (SS) - 0.03882
# RMSE scores: Validation (SS) - 0.07010
# RMSE scores: Testing (SS) - 0.11812

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
