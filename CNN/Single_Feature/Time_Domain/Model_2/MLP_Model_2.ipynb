# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/CNN/Raw_Time_WFs/Hyperparameter_Tuning_Raw_WFs/Model_JGR_MLC_Features_1/CNN_Model_2/Input_Output_Data_CNN_Model_2_Feature_1.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 1)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 300)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 300)
# Validation samples: (13208, 300)
# Testing samples: (26416, 300)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,537 (193.50 KB)
#  Trainable params: 49,537 (193.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0358 - mse: 0.0358
# Epoch 1: val_loss improved from None to 0.01702, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 2/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 2: val_loss improved from 0.01702 to 0.01513, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 3/100
# 2871/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 3: val_loss did not improve from 0.01513
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 4/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 4: val_loss improved from 0.01513 to 0.01414, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 5/100
# 2871/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 5: val_loss improved from 0.01414 to 0.01216, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 6/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5607e-04 - mse: 9.5607e-04
# Epoch 6: val_loss improved from 0.01216 to 0.01113, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 9.4962e-04 - mse: 9.4962e-04 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 7/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1059e-04 - mse: 9.1059e-04
# Epoch 7: val_loss improved from 0.01113 to 0.01028, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 9.1224e-04 - mse: 9.1224e-04 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 8/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7704e-04 - mse: 8.7704e-04
# Epoch 8: val_loss improved from 0.01028 to 0.00902, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 8.7599e-04 - mse: 8.7599e-04 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 9/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5307e-04 - mse: 8.5307e-04
# Epoch 9: val_loss improved from 0.00902 to 0.00850, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 8.5319e-04 - mse: 8.5319e-04 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 10/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4132e-04 - mse: 8.4132e-04
# Epoch 10: val_loss improved from 0.00850 to 0.00832, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 8.3610e-04 - mse: 8.3610e-04 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 11/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1581e-04 - mse: 8.1581e-04
# Epoch 11: val_loss improved from 0.00832 to 0.00772, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 8.1496e-04 - mse: 8.1496e-04 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 12/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0308e-04 - mse: 8.0308e-04
# Epoch 12: val_loss improved from 0.00772 to 0.00768, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 8.0071e-04 - mse: 8.0071e-04 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 13/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9574e-04 - mse: 7.9574e-04
# Epoch 13: val_loss improved from 0.00768 to 0.00752, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.9276e-04 - mse: 7.9276e-04 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 14/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8569e-04 - mse: 7.8569e-04
# Epoch 14: val_loss improved from 0.00752 to 0.00741, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 7.8442e-04 - mse: 7.8442e-04 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 15/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7667e-04 - mse: 7.7667e-04
# Epoch 15: val_loss improved from 0.00741 to 0.00734, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.7497e-04 - mse: 7.7497e-04 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 16/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7000e-04 - mse: 7.7000e-04
# Epoch 16: val_loss improved from 0.00734 to 0.00723, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 7.7014e-04 - mse: 7.7014e-04 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 17/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6251e-04 - mse: 7.6251e-04
# Epoch 17: val_loss did not improve from 0.00723
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.6316e-04 - mse: 7.6316e-04 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 18/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5609e-04 - mse: 7.5609e-04
# Epoch 18: val_loss improved from 0.00723 to 0.00690, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.5636e-04 - mse: 7.5636e-04 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 19/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4950e-04 - mse: 7.4950e-04
# Epoch 19: val_loss did not improve from 0.00690
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 7.4976e-04 - mse: 7.4976e-04 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 20/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4619e-04 - mse: 7.4619e-04
# Epoch 20: val_loss did not improve from 0.00690
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.4476e-04 - mse: 7.4476e-04 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 21/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4356e-04 - mse: 7.4356e-04
# Epoch 21: val_loss improved from 0.00690 to 0.00688, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 7.4167e-04 - mse: 7.4167e-04 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 22/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3789e-04 - mse: 7.3789e-04
# Epoch 22: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.3591e-04 - mse: 7.3591e-04 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 23/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2912e-04 - mse: 7.2912e-04
# Epoch 23: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.3011e-04 - mse: 7.3011e-04 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 24/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2707e-04 - mse: 7.2707e-04
# Epoch 24: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 7.2498e-04 - mse: 7.2498e-04 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 25/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2558e-04 - mse: 7.2558e-04
# Epoch 25: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.2172e-04 - mse: 7.2172e-04 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 26/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2062e-04 - mse: 7.2062e-04
# Epoch 26: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 7.1844e-04 - mse: 7.1844e-04 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 27/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1239e-04 - mse: 7.1239e-04
# Epoch 27: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 7.1373e-04 - mse: 7.1373e-04 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 28/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0978e-04 - mse: 7.0978e-04
# Epoch 28: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.1026e-04 - mse: 7.1026e-04 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 29/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1159e-04 - mse: 7.1159e-04
# Epoch 29: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 7.0959e-04 - mse: 7.0959e-04 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 30/100
# 2870/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0599e-04 - mse: 7.0599e-04
# Epoch 30: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.0601e-04 - mse: 7.0601e-04 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 31/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0486e-04 - mse: 7.0486e-04
# Epoch 31: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 7.0255e-04 - mse: 7.0255e-04 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 32/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9840e-04 - mse: 6.9840e-04
# Epoch 32: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.9738e-04 - mse: 6.9738e-04 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 33/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9414e-04 - mse: 6.9414e-04
# Epoch 33: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.9323e-04 - mse: 6.9323e-04 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 34/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8831e-04 - mse: 6.8831e-04
# Epoch 34: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 6.8830e-04 - mse: 6.8830e-04 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 35/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9097e-04 - mse: 6.9097e-04
# Epoch 35: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 6.8962e-04 - mse: 6.8962e-04 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 36/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8366e-04 - mse: 6.8366e-04
# Epoch 36: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 6.8358e-04 - mse: 6.8358e-04 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 37/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7997e-04 - mse: 6.7997e-04
# Epoch 37: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.8045e-04 - mse: 6.8045e-04 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 38/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7737e-04 - mse: 6.7737e-04
# Epoch 38: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 6.7936e-04 - mse: 6.7936e-04 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 39/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7914e-04 - mse: 6.7914e-04
# Epoch 39: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 6.7828e-04 - mse: 6.7828e-04 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 40/100
# 2872/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7451e-04 - mse: 6.7451e-04
# Epoch 40: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 6.7629e-04 - mse: 6.7629e-04 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 41/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7039e-04 - mse: 6.7039e-04
# Epoch 41: val_loss did not improve from 0.00688
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 6.7291e-04 - mse: 6.7291e-04 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 41: early stopping
# ---Training time: 383.83438706 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# R2 scores: Train (SS) - 0.97365
# R2 scores: Validation (SS) - 0.77283
# R2 scores: Testing (SS) - 0.21392
# RMSE scores: Train (SS) - 0.02646
# RMSE scores: Validation (SS) - 0.08968
# RMSE scores: Testing (SS) - 0.16341

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
