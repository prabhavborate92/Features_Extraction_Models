# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/CNN/Raw_Time_WFs/Hyperparameter_Tuning_Raw_WFs/Model_JGR_MLC_Features_1/CNN_Model_3/Input_Output_Data_CNN_Model_3_Feature_1.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 1)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 300)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 300)
# Validation samples: (13208, 300)
# Testing samples: (26416, 300)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,537 (193.50 KB)
#  Trainable params: 49,537 (193.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0362 - mse: 0.0362
# Epoch 1: val_loss improved from None to 0.00418, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 18s 5ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 2/100
# 2870/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 2: val_loss did not improve from 0.00418
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 3/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 3: val_loss did not improve from 0.00418
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 4/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0912e-04 - mse: 9.0912e-04
# Epoch 4: val_loss did not improve from 0.00418
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 8.8937e-04 - mse: 8.8937e-04 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 5/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1594e-04 - mse: 8.1594e-04
# Epoch 5: val_loss improved from 0.00418 to 0.00405, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 8.0277e-04 - mse: 8.0277e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 6/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7157e-04 - mse: 7.7157e-04
# Epoch 6: val_loss improved from 0.00405 to 0.00382, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 7.5215e-04 - mse: 7.5215e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 7/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3270e-04 - mse: 7.3270e-04
# Epoch 7: val_loss improved from 0.00382 to 0.00380, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 7.1384e-04 - mse: 7.1384e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 8/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9218e-04 - mse: 6.9218e-04
# Epoch 8: val_loss did not improve from 0.00380
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.8152e-04 - mse: 6.8152e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 9/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6029e-04 - mse: 6.6029e-04
# Epoch 9: val_loss improved from 0.00380 to 0.00371, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 6.5820e-04 - mse: 6.5820e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 10/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4308e-04 - mse: 6.4308e-04
# Epoch 10: val_loss did not improve from 0.00371
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 6.4102e-04 - mse: 6.4102e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 11/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2857e-04 - mse: 6.2857e-04
# Epoch 11: val_loss improved from 0.00371 to 0.00370, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 6.2746e-04 - mse: 6.2746e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 12/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2106e-04 - mse: 6.2106e-04
# Epoch 12: val_loss improved from 0.00370 to 0.00368, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.1915e-04 - mse: 6.1915e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 13/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1108e-04 - mse: 6.1108e-04
# Epoch 13: val_loss improved from 0.00368 to 0.00354, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.0923e-04 - mse: 6.0923e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 14/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0411e-04 - mse: 6.0411e-04
# Epoch 14: val_loss did not improve from 0.00354
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.0171e-04 - mse: 6.0171e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 15/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0172e-04 - mse: 6.0172e-04
# Epoch 15: val_loss improved from 0.00354 to 0.00352, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.9606e-04 - mse: 5.9606e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 16/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9214e-04 - mse: 5.9214e-04
# Epoch 16: val_loss did not improve from 0.00352
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 5.9091e-04 - mse: 5.9091e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 17/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8560e-04 - mse: 5.8560e-04
# Epoch 17: val_loss did not improve from 0.00352
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.8489e-04 - mse: 5.8489e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 18/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8086e-04 - mse: 5.8086e-04
# Epoch 18: val_loss improved from 0.00352 to 0.00349, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.8034e-04 - mse: 5.8034e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 19/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7280e-04 - mse: 5.7280e-04
# Epoch 19: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 5.7347e-04 - mse: 5.7347e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 20/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6960e-04 - mse: 5.6960e-04
# Epoch 20: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 5.6921e-04 - mse: 5.6921e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 21/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6703e-04 - mse: 5.6703e-04
# Epoch 21: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.6689e-04 - mse: 5.6689e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 22/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6154e-04 - mse: 5.6154e-04
# Epoch 22: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 5.6218e-04 - mse: 5.6218e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 23/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5960e-04 - mse: 5.5960e-04
# Epoch 23: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.6096e-04 - mse: 5.6096e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 24/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5464e-04 - mse: 5.5464e-04
# Epoch 24: val_loss improved from 0.00349 to 0.00349, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 24: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.5769e-04 - mse: 5.5769e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 25/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5254e-04 - mse: 5.5254e-04
# Epoch 25: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 5.5479e-04 - mse: 5.5479e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 26/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4984e-04 - mse: 5.4984e-04
# Epoch 26: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.5246e-04 - mse: 5.5246e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 27/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4672e-04 - mse: 5.4672e-04
# Epoch 27: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.4846e-04 - mse: 5.4846e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 28/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4501e-04 - mse: 5.4501e-04
# Epoch 28: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 5.4585e-04 - mse: 5.4585e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 29/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4105e-04 - mse: 5.4105e-04
# Epoch 29: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.4309e-04 - mse: 5.4309e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 30/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4192e-04 - mse: 5.4192e-04
# Epoch 30: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.4086e-04 - mse: 5.4086e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 31/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3851e-04 - mse: 5.3851e-04
# Epoch 31: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 5.3912e-04 - mse: 5.3912e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 32/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3713e-04 - mse: 5.3713e-04
# Epoch 32: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.3718e-04 - mse: 5.3718e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 33/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3527e-04 - mse: 5.3527e-04
# Epoch 33: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 5.3627e-04 - mse: 5.3627e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 34/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2934e-04 - mse: 5.2934e-04
# Epoch 34: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 5.3167e-04 - mse: 5.3167e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 35/100
# 2871/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2863e-04 - mse: 5.2863e-04
# Epoch 35: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.2980e-04 - mse: 5.2980e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 36/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2537e-04 - mse: 5.2537e-04
# Epoch 36: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 5.2713e-04 - mse: 5.2713e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 37/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2276e-04 - mse: 5.2276e-04
# Epoch 37: val_loss did not improve from 0.00349
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 5.2589e-04 - mse: 5.2589e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 38/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2064e-04 - mse: 5.2064e-04
# Epoch 38: val_loss improved from 0.00349 to 0.00346, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 38: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.2265e-04 - mse: 5.2265e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 39/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1686e-04 - mse: 5.1686e-04
# Epoch 39: val_loss did not improve from 0.00346
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 5.2043e-04 - mse: 5.2043e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 40/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1496e-04 - mse: 5.1496e-04
# Epoch 40: val_loss did not improve from 0.00346
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.1858e-04 - mse: 5.1858e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 41/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1267e-04 - mse: 5.1267e-04
# Epoch 41: val_loss did not improve from 0.00346
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.1532e-04 - mse: 5.1532e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 42/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1098e-04 - mse: 5.1098e-04
# Epoch 42: val_loss did not improve from 0.00346
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 5.1330e-04 - mse: 5.1330e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 43/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0979e-04 - mse: 5.0979e-04
# Epoch 43: val_loss improved from 0.00346 to 0.00343, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 43: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.1319e-04 - mse: 5.1319e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 44/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0837e-04 - mse: 5.0837e-04
# Epoch 44: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 5.1107e-04 - mse: 5.1107e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 45/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0699e-04 - mse: 5.0699e-04
# Epoch 45: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.1029e-04 - mse: 5.1029e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 46/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0576e-04 - mse: 5.0576e-04
# Epoch 46: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.0838e-04 - mse: 5.0838e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 47/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0447e-04 - mse: 5.0447e-04
# Epoch 47: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 5.0726e-04 - mse: 5.0726e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 48/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0367e-04 - mse: 5.0367e-04
# Epoch 48: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.0660e-04 - mse: 5.0660e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 49/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0164e-04 - mse: 5.0164e-04
# Epoch 49: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.0420e-04 - mse: 5.0420e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 50/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0072e-04 - mse: 5.0072e-04
# Epoch 50: val_loss improved from 0.00343 to 0.00339, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 50: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 5.0321e-04 - mse: 5.0321e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 51/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9901e-04 - mse: 4.9901e-04
# Epoch 51: val_loss improved from 0.00339 to 0.00337, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 51: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 5.0181e-04 - mse: 5.0181e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 52/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9579e-04 - mse: 4.9579e-04
# Epoch 52: val_loss did not improve from 0.00337
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 4.9957e-04 - mse: 4.9957e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 53/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9539e-04 - mse: 4.9539e-04
# Epoch 53: val_loss did not improve from 0.00337
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.9849e-04 - mse: 4.9849e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 54/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9438e-04 - mse: 4.9438e-04
# Epoch 54: val_loss did not improve from 0.00337
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.9839e-04 - mse: 4.9839e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 55/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9262e-04 - mse: 4.9262e-04
# Epoch 55: val_loss did not improve from 0.00337
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.9607e-04 - mse: 4.9607e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 56/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9323e-04 - mse: 4.9323e-04
# Epoch 56: val_loss improved from 0.00337 to 0.00332, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 56: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 4.9496e-04 - mse: 4.9496e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 57/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8996e-04 - mse: 4.8996e-04
# Epoch 57: val_loss did not improve from 0.00332
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.9410e-04 - mse: 4.9410e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 58/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9024e-04 - mse: 4.9024e-04
# Epoch 58: val_loss did not improve from 0.00332
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.9277e-04 - mse: 4.9277e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 59/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8738e-04 - mse: 4.8738e-04
# Epoch 59: val_loss did not improve from 0.00332
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.9108e-04 - mse: 4.9108e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 60/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8939e-04 - mse: 4.8939e-04
# Epoch 60: val_loss did not improve from 0.00332
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.9077e-04 - mse: 4.9077e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 61/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8749e-04 - mse: 4.8749e-04
# Epoch 61: val_loss did not improve from 0.00332
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.9000e-04 - mse: 4.9000e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 62/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8623e-04 - mse: 4.8623e-04
# Epoch 62: val_loss improved from 0.00332 to 0.00331, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 62: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.8922e-04 - mse: 4.8922e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 63/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8635e-04 - mse: 4.8635e-04
# Epoch 63: val_loss did not improve from 0.00331
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.8822e-04 - mse: 4.8822e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 64/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8674e-04 - mse: 4.8674e-04
# Epoch 64: val_loss did not improve from 0.00331
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.8687e-04 - mse: 4.8687e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 65/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8461e-04 - mse: 4.8461e-04
# Epoch 65: val_loss did not improve from 0.00331
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 4.8608e-04 - mse: 4.8608e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 66/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8313e-04 - mse: 4.8313e-04
# Epoch 66: val_loss did not improve from 0.00331
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.8515e-04 - mse: 4.8515e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 67/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8315e-04 - mse: 4.8315e-04
# Epoch 67: val_loss did not improve from 0.00331
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.8414e-04 - mse: 4.8414e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 68/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8130e-04 - mse: 4.8130e-04
# Epoch 68: val_loss did not improve from 0.00331
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.8269e-04 - mse: 4.8269e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 69/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8073e-04 - mse: 4.8073e-04
# Epoch 69: val_loss did not improve from 0.00331
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.8185e-04 - mse: 4.8185e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 70/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7847e-04 - mse: 4.7847e-04
# Epoch 70: val_loss improved from 0.00331 to 0.00330, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 70: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.8060e-04 - mse: 4.8060e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 71/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7811e-04 - mse: 4.7811e-04
# Epoch 71: val_loss did not improve from 0.00330
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.8062e-04 - mse: 4.8062e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 72/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7559e-04 - mse: 4.7559e-04
# Epoch 72: val_loss improved from 0.00330 to 0.00326, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 72: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.7885e-04 - mse: 4.7885e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 73/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7500e-04 - mse: 4.7500e-04
# Epoch 73: val_loss did not improve from 0.00326
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.7771e-04 - mse: 4.7771e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 74/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7466e-04 - mse: 4.7466e-04
# Epoch 74: val_loss did not improve from 0.00326
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.7767e-04 - mse: 4.7767e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 75/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7215e-04 - mse: 4.7215e-04
# Epoch 75: val_loss did not improve from 0.00326
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 4.7647e-04 - mse: 4.7647e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 76/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7300e-04 - mse: 4.7300e-04
# Epoch 76: val_loss did not improve from 0.00326
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.7660e-04 - mse: 4.7660e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 77/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7070e-04 - mse: 4.7070e-04
# Epoch 77: val_loss did not improve from 0.00326
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.7522e-04 - mse: 4.7522e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 78/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6992e-04 - mse: 4.6992e-04
# Epoch 78: val_loss improved from 0.00326 to 0.00323, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 78: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.7465e-04 - mse: 4.7465e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 79/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6904e-04 - mse: 4.6904e-04
# Epoch 79: val_loss did not improve from 0.00323
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 4.7331e-04 - mse: 4.7331e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 80/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7000e-04 - mse: 4.7000e-04
# Epoch 80: val_loss did not improve from 0.00323
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.7244e-04 - mse: 4.7244e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 81/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6715e-04 - mse: 4.6715e-04
# Epoch 81: val_loss did not improve from 0.00323
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.7114e-04 - mse: 4.7114e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 82/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6713e-04 - mse: 4.6713e-04
# Epoch 82: val_loss improved from 0.00323 to 0.00321, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 82: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 4.7109e-04 - mse: 4.7109e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 83/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6859e-04 - mse: 4.6859e-04
# Epoch 83: val_loss did not improve from 0.00321
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.7154e-04 - mse: 4.7154e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 84/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6576e-04 - mse: 4.6576e-04
# Epoch 84: val_loss did not improve from 0.00321
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 4.7024e-04 - mse: 4.7024e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 85/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6483e-04 - mse: 4.6483e-04
# Epoch 85: val_loss did not improve from 0.00321
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 4.6852e-04 - mse: 4.6852e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 86/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6644e-04 - mse: 4.6644e-04
# Epoch 86: val_loss did not improve from 0.00321
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.6956e-04 - mse: 4.6956e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 87/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6512e-04 - mse: 4.6512e-04
# Epoch 87: val_loss did not improve from 0.00321
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.6811e-04 - mse: 4.6811e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 88/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6343e-04 - mse: 4.6343e-04
# Epoch 88: val_loss improved from 0.00321 to 0.00320, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 88: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.6671e-04 - mse: 4.6671e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 89/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6410e-04 - mse: 4.6410e-04
# Epoch 89: val_loss improved from 0.00320 to 0.00320, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 89: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.6722e-04 - mse: 4.6722e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 90/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6196e-04 - mse: 4.6196e-04
# Epoch 90: val_loss did not improve from 0.00320
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 4.6550e-04 - mse: 4.6550e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 91/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6174e-04 - mse: 4.6174e-04
# Epoch 91: val_loss did not improve from 0.00320
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.6473e-04 - mse: 4.6473e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 92/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6180e-04 - mse: 4.6180e-04
# Epoch 92: val_loss did not improve from 0.00320
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 4.6520e-04 - mse: 4.6520e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 93/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6089e-04 - mse: 4.6089e-04
# Epoch 93: val_loss improved from 0.00320 to 0.00312, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 93: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.6450e-04 - mse: 4.6450e-04 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 94/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6047e-04 - mse: 4.6047e-04
# Epoch 94: val_loss did not improve from 0.00312
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 4.6367e-04 - mse: 4.6367e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 95/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6103e-04 - mse: 4.6103e-04
# Epoch 95: val_loss did not improve from 0.00312
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.6349e-04 - mse: 4.6349e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 96/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6034e-04 - mse: 4.6034e-04
# Epoch 96: val_loss did not improve from 0.00312
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.6344e-04 - mse: 4.6344e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 97/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6059e-04 - mse: 4.6059e-04
# Epoch 97: val_loss did not improve from 0.00312
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 4.6342e-04 - mse: 4.6342e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 98/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5924e-04 - mse: 4.5924e-04
# Epoch 98: val_loss did not improve from 0.00312
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 4.6206e-04 - mse: 4.6206e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 99/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5931e-04 - mse: 4.5931e-04
# Epoch 99: val_loss did not improve from 0.00312
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.6114e-04 - mse: 4.6114e-04 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 100/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5655e-04 - mse: 4.5655e-04
# Epoch 100: val_loss improved from 0.00312 to 0.00310, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 100: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 4.6118e-04 - mse: 4.6118e-04 - val_loss: 0.0031 - val_mse: 0.0031
# ---Training time: 1060.17837286 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# R2 scores: Train (SS) - 0.98187
# R2 scores: Validation (SS) - 0.91246
# R2 scores: Testing (SS) - 0.48590
# RMSE scores: Train (SS) - 0.02195
# RMSE scores: Validation (SS) - 0.05567
# RMSE scores: Testing (SS) - 0.13215

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
