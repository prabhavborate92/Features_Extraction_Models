# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/CNN/Raw_Time_WFs/Hyperparameter_Tuning_Raw_WFs/Model_JGR_MLC_Features_1/CNN_Model_1/Input_Output_Data_CNN_Model_1_Feature_1.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 1)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 300)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 300)
# Validation samples: (13208, 300)
# Testing samples: (26416, 300)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,537 (193.50 KB)
#  Trainable params: 49,537 (193.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0350 - mse: 0.0350
# Epoch 1: val_loss improved from None to 0.00442, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 2/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 2: val_loss improved from 0.00442 to 0.00376, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 3/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 3: val_loss did not improve from 0.00376
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 4/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 4: val_loss did not improve from 0.00376
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 5/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 5: val_loss improved from 0.00376 to 0.00331, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 6/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 6: val_loss improved from 0.00331 to 0.00307, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 7/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 7: val_loss improved from 0.00307 to 0.00282, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 8/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 8: val_loss improved from 0.00282 to 0.00261, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 9/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 9: val_loss improved from 0.00261 to 0.00239, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 10/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 10: val_loss improved from 0.00239 to 0.00228, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 11/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7804e-04 - mse: 9.7804e-04
# Epoch 11: val_loss improved from 0.00228 to 0.00226, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 9.8709e-04 - mse: 9.8709e-04 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 12/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5984e-04 - mse: 9.5984e-04
# Epoch 12: val_loss improved from 0.00226 to 0.00219, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 9.6808e-04 - mse: 9.6808e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 13/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3845e-04 - mse: 9.3845e-04
# Epoch 13: val_loss did not improve from 0.00219
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 9.4652e-04 - mse: 9.4652e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 14/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2058e-04 - mse: 9.2058e-04
# Epoch 14: val_loss improved from 0.00219 to 0.00218, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 9.3263e-04 - mse: 9.3263e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 15/100
# 2867/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1654e-04 - mse: 9.1654e-04
# Epoch 15: val_loss did not improve from 0.00218
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 9.2443e-04 - mse: 9.2443e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 16/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0184e-04 - mse: 9.0184e-04
# Epoch 16: val_loss improved from 0.00218 to 0.00212, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 9.1277e-04 - mse: 9.1277e-04 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 17/100
# 2868/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9402e-04 - mse: 8.9402e-04
# Epoch 17: val_loss did not improve from 0.00212
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 9.0129e-04 - mse: 9.0129e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 18/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8562e-04 - mse: 8.8562e-04
# Epoch 18: val_loss did not improve from 0.00212
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 8.9708e-04 - mse: 8.9708e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 19/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8194e-04 - mse: 8.8194e-04
# Epoch 19: val_loss did not improve from 0.00212
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 8.8915e-04 - mse: 8.8915e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 20/100
# 2868/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7519e-04 - mse: 8.7519e-04
# Epoch 20: val_loss did not improve from 0.00212
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 8.7845e-04 - mse: 8.7845e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 21/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6009e-04 - mse: 8.6009e-04
# Epoch 21: val_loss did not improve from 0.00212
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 8.6779e-04 - mse: 8.6779e-04 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 22/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5696e-04 - mse: 8.5696e-04
# Epoch 22: val_loss improved from 0.00212 to 0.00211, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 22: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 8.6121e-04 - mse: 8.6121e-04 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 23/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5182e-04 - mse: 8.5182e-04
# Epoch 23: val_loss did not improve from 0.00211
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 8.5575e-04 - mse: 8.5575e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 24/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4562e-04 - mse: 8.4562e-04
# Epoch 24: val_loss did not improve from 0.00211
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 8.4766e-04 - mse: 8.4766e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 25/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4383e-04 - mse: 8.4383e-04
# Epoch 25: val_loss improved from 0.00211 to 0.00209, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 25: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 8.4756e-04 - mse: 8.4756e-04 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 26/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2726e-04 - mse: 8.2726e-04
# Epoch 26: val_loss improved from 0.00209 to 0.00205, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 26: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 8.3538e-04 - mse: 8.3538e-04 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 27/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2080e-04 - mse: 8.2080e-04
# Epoch 27: val_loss improved from 0.00205 to 0.00205, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 27: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 8.2801e-04 - mse: 8.2801e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 28/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2634e-04 - mse: 8.2634e-04
# Epoch 28: val_loss improved from 0.00205 to 0.00204, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 28: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 8.2891e-04 - mse: 8.2891e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 29/100
# 2870/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1365e-04 - mse: 8.1365e-04
# Epoch 29: val_loss improved from 0.00204 to 0.00198, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 29: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 8.2306e-04 - mse: 8.2306e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 30/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1431e-04 - mse: 8.1431e-04
# Epoch 30: val_loss did not improve from 0.00198
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 8.2275e-04 - mse: 8.2275e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 31/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0359e-04 - mse: 8.0359e-04
# Epoch 31: val_loss improved from 0.00198 to 0.00194, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 31: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 8.0955e-04 - mse: 8.0955e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 32/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9622e-04 - mse: 7.9622e-04
# Epoch 32: val_loss did not improve from 0.00194
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 8.0438e-04 - mse: 8.0438e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 33/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8831e-04 - mse: 7.8831e-04
# Epoch 33: val_loss did not improve from 0.00194
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.9596e-04 - mse: 7.9596e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 34/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8549e-04 - mse: 7.8549e-04
# Epoch 34: val_loss did not improve from 0.00194
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.9289e-04 - mse: 7.9289e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 35/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8242e-04 - mse: 7.8242e-04
# Epoch 35: val_loss did not improve from 0.00194
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.9052e-04 - mse: 7.9052e-04 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 36/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8266e-04 - mse: 7.8266e-04
# Epoch 36: val_loss did not improve from 0.00194
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.8580e-04 - mse: 7.8580e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 37/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7001e-04 - mse: 7.7001e-04
# Epoch 37: val_loss did not improve from 0.00194
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.7747e-04 - mse: 7.7747e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 38/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7556e-04 - mse: 7.7556e-04
# Epoch 38: val_loss did not improve from 0.00194
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.7797e-04 - mse: 7.7797e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 39/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7554e-04 - mse: 7.7554e-04
# Epoch 39: val_loss improved from 0.00194 to 0.00194, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 39: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.7600e-04 - mse: 7.7600e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 40/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6608e-04 - mse: 7.6608e-04
# Epoch 40: val_loss improved from 0.00194 to 0.00190, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 40: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.7185e-04 - mse: 7.7185e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 41/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6157e-04 - mse: 7.6157e-04
# Epoch 41: val_loss did not improve from 0.00190
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.6599e-04 - mse: 7.6599e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 42/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6130e-04 - mse: 7.6130e-04
# Epoch 42: val_loss did not improve from 0.00190
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.6466e-04 - mse: 7.6466e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 43/100
# 2866/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6404e-04 - mse: 7.6404e-04
# Epoch 43: val_loss did not improve from 0.00190
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.6515e-04 - mse: 7.6515e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 44/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5656e-04 - mse: 7.5656e-04
# Epoch 44: val_loss improved from 0.00190 to 0.00189, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 44: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.5989e-04 - mse: 7.5989e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 45/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6264e-04 - mse: 7.6264e-04
# Epoch 45: val_loss did not improve from 0.00189
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.6112e-04 - mse: 7.6112e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 46/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5147e-04 - mse: 7.5147e-04
# Epoch 46: val_loss did not improve from 0.00189
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.5334e-04 - mse: 7.5334e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 47/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4747e-04 - mse: 7.4747e-04
# Epoch 47: val_loss did not improve from 0.00189
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 7.5308e-04 - mse: 7.5308e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 48/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4523e-04 - mse: 7.4523e-04
# Epoch 48: val_loss improved from 0.00189 to 0.00184, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 48: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.5081e-04 - mse: 7.5081e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 49/100
# 2871/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4754e-04 - mse: 7.4754e-04
# Epoch 49: val_loss did not improve from 0.00184
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.4953e-04 - mse: 7.4953e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 50/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3847e-04 - mse: 7.3847e-04
# Epoch 50: val_loss did not improve from 0.00184
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.4395e-04 - mse: 7.4395e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 51/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4511e-04 - mse: 7.4511e-04
# Epoch 51: val_loss improved from 0.00184 to 0.00182, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 51: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.4513e-04 - mse: 7.4513e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 52/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4201e-04 - mse: 7.4201e-04
# Epoch 52: val_loss did not improve from 0.00182
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.4425e-04 - mse: 7.4425e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 53/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4171e-04 - mse: 7.4171e-04
# Epoch 53: val_loss improved from 0.00182 to 0.00179, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 53: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 7.4227e-04 - mse: 7.4227e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 54/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3543e-04 - mse: 7.3543e-04
# Epoch 54: val_loss did not improve from 0.00179
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 7.3491e-04 - mse: 7.3491e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 55/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3579e-04 - mse: 7.3579e-04
# Epoch 55: val_loss did not improve from 0.00179
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.3632e-04 - mse: 7.3632e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 56/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3195e-04 - mse: 7.3195e-04
# Epoch 56: val_loss did not improve from 0.00179
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.2764e-04 - mse: 7.2764e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 57/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3271e-04 - mse: 7.3271e-04
# Epoch 57: val_loss did not improve from 0.00179
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 7.3050e-04 - mse: 7.3050e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 58/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2873e-04 - mse: 7.2873e-04
# Epoch 58: val_loss did not improve from 0.00179
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.2893e-04 - mse: 7.2893e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 59/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2672e-04 - mse: 7.2672e-04
# Epoch 59: val_loss did not improve from 0.00179
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.2565e-04 - mse: 7.2565e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 60/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2381e-04 - mse: 7.2381e-04
# Epoch 60: val_loss improved from 0.00179 to 0.00178, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 60: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.2364e-04 - mse: 7.2364e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 61/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2402e-04 - mse: 7.2402e-04
# Epoch 61: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 7.1920e-04 - mse: 7.1920e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 62/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1916e-04 - mse: 7.1916e-04
# Epoch 62: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.1755e-04 - mse: 7.1755e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 63/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1932e-04 - mse: 7.1932e-04
# Epoch 63: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 7.1830e-04 - mse: 7.1830e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 64/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1806e-04 - mse: 7.1806e-04
# Epoch 64: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.1349e-04 - mse: 7.1349e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 65/100
# 2871/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1140e-04 - mse: 7.1140e-04
# Epoch 65: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 7.1143e-04 - mse: 7.1143e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 66/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1498e-04 - mse: 7.1498e-04
# Epoch 66: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.0927e-04 - mse: 7.0927e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 67/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0726e-04 - mse: 7.0726e-04
# Epoch 67: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.0545e-04 - mse: 7.0545e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 68/100
# 2872/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1036e-04 - mse: 7.1036e-04
# Epoch 68: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 7.0667e-04 - mse: 7.0667e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 69/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0766e-04 - mse: 7.0766e-04
# Epoch 69: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 7.0485e-04 - mse: 7.0485e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 70/100
# 2871/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0991e-04 - mse: 7.0991e-04
# Epoch 70: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 7.0975e-04 - mse: 7.0975e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 71/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0029e-04 - mse: 7.0029e-04
# Epoch 71: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.9829e-04 - mse: 6.9829e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 72/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0594e-04 - mse: 7.0594e-04
# Epoch 72: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.0211e-04 - mse: 7.0211e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 73/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9526e-04 - mse: 6.9526e-04
# Epoch 73: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.9611e-04 - mse: 6.9611e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 74/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9988e-04 - mse: 6.9988e-04
# Epoch 74: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 6.9768e-04 - mse: 6.9768e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 75/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0057e-04 - mse: 7.0057e-04
# Epoch 75: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.9900e-04 - mse: 6.9900e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 76/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9991e-04 - mse: 6.9991e-04
# Epoch 76: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 6.9839e-04 - mse: 6.9839e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 77/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9144e-04 - mse: 6.9144e-04
# Epoch 77: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.9290e-04 - mse: 6.9290e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 78/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9003e-04 - mse: 6.9003e-04
# Epoch 78: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 6.9012e-04 - mse: 6.9012e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 79/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8982e-04 - mse: 6.8982e-04
# Epoch 79: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 6.8955e-04 - mse: 6.8955e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 80/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9577e-04 - mse: 6.9577e-04
# Epoch 80: val_loss did not improve from 0.00178
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 6.9135e-04 - mse: 6.9135e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 80: early stopping
# ---Training time: 672.80946565 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# R2 scores: Train (SS) - 0.97509
# R2 scores: Validation (SS) - 0.94441
# R2 scores: Testing (SS) - 0.67948
# RMSE scores: Train (SS) - 0.02573
# RMSE scores: Validation (SS) - 0.04436
# RMSE scores: Testing (SS) - 0.10435

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
