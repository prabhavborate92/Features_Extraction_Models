# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/CNN/Spectrum/JGR_MLC_CNN_Same_Window_Baseline/Input_Output_Data_CNN_Same_Window.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132082, 300, 1)
# Target shape (SS), Y =  (132082,)
# After reshaping, X =  (132082, 300)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92456, 300)
# Validation samples: (13209, 300)
# Testing samples: (26417, 300)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,537 (193.50 KB)
#  Trainable params: 49,537 (193.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2862/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0679 - mse: 0.0679
# Epoch 1: val_loss improved from None to 0.03909, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0391 - val_mse: 0.0391
# Epoch 2/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0215 - mse: 0.0215
# Epoch 2: val_loss improved from 0.03909 to 0.03741, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0374 - val_mse: 0.0374
# Epoch 3/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160 - mse: 0.0160
# Epoch 3: val_loss improved from 0.03741 to 0.03577, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0358 - val_mse: 0.0358
# Epoch 4/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0135 - mse: 0.0135
# Epoch 4: val_loss did not improve from 0.03577
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0368 - val_mse: 0.0368
# Epoch 5/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0118 - mse: 0.0118
# Epoch 5: val_loss improved from 0.03577 to 0.03234, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0323 - val_mse: 0.0323
# Epoch 6/100
# 2867/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0108 - mse: 0.0108
# Epoch 6: val_loss improved from 0.03234 to 0.02734, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0273 - val_mse: 0.0273
# Epoch 7/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - mse: 0.0099
# Epoch 7: val_loss did not improve from 0.02734
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0297 - val_mse: 0.0297
# Epoch 8/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mse: 0.0094
# Epoch 8: val_loss did not improve from 0.02734
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0309 - val_mse: 0.0309
# Epoch 9/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - mse: 0.0087
# Epoch 9: val_loss did not improve from 0.02734
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0295 - val_mse: 0.0295
# Epoch 10/100
# 2863/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - mse: 0.0083
# Epoch 10: val_loss improved from 0.02734 to 0.02591, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 11/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - mse: 0.0080
# Epoch 11: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0276 - val_mse: 0.0276
# Epoch 12/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mse: 0.0081
# Epoch 12: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0274 - val_mse: 0.0274
# Epoch 13/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mse: 0.0077
# Epoch 13: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0281 - val_mse: 0.0281
# Epoch 14/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mse: 0.0072
# Epoch 14: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 15/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mse: 0.0070
# Epoch 15: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0272 - val_mse: 0.0272
# Epoch 16/100
# 2870/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mse: 0.0066
# Epoch 16: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0276 - val_mse: 0.0276
# Epoch 17/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mse: 0.0065
# Epoch 17: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0273 - val_mse: 0.0273
# Epoch 18/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mse: 0.0063
# Epoch 18: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 19/100
# 2866/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061 - mse: 0.0061
# Epoch 19: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0313 - val_mse: 0.0313
# Epoch 20/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - mse: 0.0060
# Epoch 20: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 21/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - mse: 0.0059
# Epoch 21: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0314 - val_mse: 0.0314
# Epoch 22/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mse: 0.0057
# Epoch 22: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0270 - val_mse: 0.0270
# Epoch 23/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - mse: 0.0056
# Epoch 23: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0265 - val_mse: 0.0265
# Epoch 24/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mse: 0.0054
# Epoch 24: val_loss did not improve from 0.02591
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0268 - val_mse: 0.0268
# Epoch 25/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - mse: 0.0053
# Epoch 25: val_loss improved from 0.02591 to 0.02484, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 25: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0248 - val_mse: 0.0248
# Epoch 26/100
# 2871/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - mse: 0.0053
# Epoch 26: val_loss did not improve from 0.02484
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 27/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mse: 0.0050
# Epoch 27: val_loss did not improve from 0.02484
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0280 - val_mse: 0.0280
# Epoch 28/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mse: 0.0051
# Epoch 28: val_loss improved from 0.02484 to 0.02412, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 28: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0241 - val_mse: 0.0241
# Epoch 29/100
# 2864/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mse: 0.0050
# Epoch 29: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 30/100
# 2862/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mse: 0.0049
# Epoch 30: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 31/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mse: 0.0049
# Epoch 31: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 32/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 32: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 33/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 33: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0256 - val_mse: 0.0256
# Epoch 34/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 34: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0258 - val_mse: 0.0258
# Epoch 35/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mse: 0.0047
# Epoch 35: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0282 - val_mse: 0.0282
# Epoch 36/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mse: 0.0045
# Epoch 36: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0252 - val_mse: 0.0252
# Epoch 37/100
# 2869/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mse: 0.0047
# Epoch 37: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0256 - val_mse: 0.0256
# Epoch 38/100
# 2872/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mse: 0.0044
# Epoch 38: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0281 - val_mse: 0.0281
# Epoch 39/100
# 2870/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mse: 0.0044
# Epoch 39: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 40/100
# 2868/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mse: 0.0044
# Epoch 40: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0255 - val_mse: 0.0255
# Epoch 41/100
# 2859/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mse: 0.0042
# Epoch 41: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0255 - val_mse: 0.0255
# Epoch 42/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mse: 0.0042
# Epoch 42: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0250 - val_mse: 0.0250
# Epoch 43/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mse: 0.0042
# Epoch 43: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0286 - val_mse: 0.0286
# Epoch 44/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mse: 0.0043
# Epoch 44: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 45/100
# 2866/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mse: 0.0041
# Epoch 45: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0269 - val_mse: 0.0269
# Epoch 46/100
# 2862/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mse: 0.0043
# Epoch 46: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0263 - val_mse: 0.0263
# Epoch 47/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mse: 0.0041
# Epoch 47: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0273 - val_mse: 0.0273
# Epoch 48/100
# 2872/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mse: 0.0040
# Epoch 48: val_loss did not improve from 0.02412
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 48: early stopping
# ---Training time: 275.95112658 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 3s 853us/step
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# R2 scores: Train (SS) - 0.85523
# R2 scores: Validation (SS) - 0.26485
# R2 scores: Testing (SS) - 0.28690
# RMSE scores: Train (SS) - 0.06203
# RMSE scores: Validation (SS) - 0.16135
# RMSE scores: Testing (SS) - 0.15562

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
