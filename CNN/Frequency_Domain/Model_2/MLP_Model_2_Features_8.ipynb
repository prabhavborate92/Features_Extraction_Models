# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
# tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Entire_Signal/CNN_With_Spectra/CNN_Models/Hyperparameter_Tuning_CNN_spectra/Model_2/Input_Output_Data_Model_2.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten(), 'F3':data1['F3'].flatten(), 'F4':data1['F4'].flatten(), 'F5':data1['F5'].flatten(),
                   'F6':data1['F6'].flatten(), 'F7':data1['F7'].flatten(), 'F8':data1['F8'].flatten(),'SS':data1['SS'].flatten()})
df = df[['F1','F2','F3','F4','F5','F6','F7','F8','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132106, 300, 8)
# Target shape (SS), Y =  (132106,)
# After reshaping, X =  (132106, 2400)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92473, 2400)
# Validation samples: (13211, 2400)
# Testing samples: (26422, 2400)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(2400,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(1024,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(256,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(64, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 2400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     2,458,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,737,537 (10.44 MB)
#  Trainable params: 2,737,537 (10.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0393 - mse: 0.0393
# Epoch 1: val_loss improved from inf to 0.01304, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 154s 53ms/step - loss: 0.0393 - mse: 0.0393 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 2/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 2: val_loss improved from 0.01304 to 0.00770, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 192s 49ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 3/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 3: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 201s 49ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 4/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 4: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 49ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 5/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 5: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 143s 49ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 6/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 6: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 202s 49ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 7/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 7: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 197s 48ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 8/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 8: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 147s 49ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 9/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 9: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 201s 49ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 10/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 10: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 49ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 11/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 9.9790e-04 - mse: 9.9790e-04
# Epoch 11: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 149s 52ms/step - loss: 9.9789e-04 - mse: 9.9789e-04 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 12/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 9.2834e-04 - mse: 9.2834e-04
# Epoch 12: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 194s 49ms/step - loss: 9.2834e-04 - mse: 9.2834e-04 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 13/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 9.4048e-04 - mse: 9.4048e-04
# Epoch 13: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 141s 48ms/step - loss: 9.4047e-04 - mse: 9.4047e-04 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 14/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 8.8533e-04 - mse: 8.8533e-04
# Epoch 14: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 145s 50ms/step - loss: 8.8533e-04 - mse: 8.8533e-04 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 15/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 8.8338e-04 - mse: 8.8338e-04
# Epoch 15: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 200s 49ms/step - loss: 8.8337e-04 - mse: 8.8337e-04 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 16/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 8.3904e-04 - mse: 8.3904e-04
# Epoch 16: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 143s 49ms/step - loss: 8.3904e-04 - mse: 8.3904e-04 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 17/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 8.1901e-04 - mse: 8.1901e-04
# Epoch 17: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 203s 50ms/step - loss: 8.1901e-04 - mse: 8.1901e-04 - val_loss: 0.0215 - val_mse: 0.0215
# Epoch 18/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 8.1032e-04 - mse: 8.1032e-04
# Epoch 18: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 149s 52ms/step - loss: 8.1031e-04 - mse: 8.1031e-04 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 19/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 8.1316e-04 - mse: 8.1316e-04
# Epoch 19: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 198s 50ms/step - loss: 8.1315e-04 - mse: 8.1315e-04 - val_loss: 0.0203 - val_mse: 0.0203
# Epoch 20/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 7.8842e-04 - mse: 7.8842e-04
# Epoch 20: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 200s 50ms/step - loss: 7.8841e-04 - mse: 7.8841e-04 - val_loss: 0.0217 - val_mse: 0.0217
# Epoch 21/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.6060e-04 - mse: 7.6060e-04
# Epoch 21: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 202s 50ms/step - loss: 7.6059e-04 - mse: 7.6059e-04 - val_loss: 0.0238 - val_mse: 0.0238
# Epoch 22/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 7.5625e-04 - mse: 7.5625e-04
# Epoch 22: val_loss did not improve from 0.00770
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 203s 50ms/step - loss: 7.5624e-04 - mse: 7.5624e-04 - val_loss: 0.0254 - val_mse: 0.0254
# Epoch 22: early stopping
# ---Training time: 3852.99880695 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
#   14/2890 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(32, 2400))
#   warnings.warn(msg)
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 29s 10ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(None, 2400))
#   warnings.warn(msg)
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step
# R2 scores: Train (SS) - 0.97980
# R2 scores: Validation (SS) - 0.28314
# R2 scores: Testing (SS) - -0.71959
# RMSE scores: Train (SS) - 0.02317
# RMSE scores: Validation (SS) - 0.15932
# RMSE scores: Testing (SS) - 0.24169

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
