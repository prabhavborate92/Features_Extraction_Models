# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
# tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Entire_Signal/CNN_With_Spectra/CNN_Models/Hyperparameter_Tuning_CNN_spectra/Model_1/Input_Output_Data_Model_1.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten(), 'F3':data1['F3'].flatten(), 'F4':data1['F4'].flatten(), 'F5':data1['F5'].flatten(),
                   'F6':data1['F6'].flatten(), 'F7':data1['F7'].flatten(), 'F8':data1['F8'].flatten(),'SS':data1['SS'].flatten()})
df = df[['F1','F2','F3','F4','F5','F6','F7','F8','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132106, 300, 8)
# Target shape (SS), Y =  (132106,)
# After reshaping, X =  (132106, 2400)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92473, 2400)
# Validation samples: (13211, 2400)
# Testing samples: (26422, 2400)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(2400,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(1024,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(256,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(64, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 2400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     2,458,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,737,537 (10.44 MB)
#  Trainable params: 2,737,537 (10.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0195 - mse: 0.0195
# Epoch 1: val_loss improved from inf to 0.00803, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 130s 44ms/step - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 2/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 2: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 127s 39ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 3/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 3: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 116s 40ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 4/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 4: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 136s 38ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 5/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 5: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 145s 39ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 6/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 6: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 141s 39ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 7/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 7: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 110s 38ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 8/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 8: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 114s 39ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 9/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 9: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 39ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 10/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 10: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 113s 39ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 11/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 11: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 145s 40ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 12/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 12: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 110s 38ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 13/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 13: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 141s 38ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 14/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 14: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 38ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 15/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 9.7210e-04 - mse: 9.7210e-04
# Epoch 15: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 145s 39ms/step - loss: 9.7209e-04 - mse: 9.7209e-04 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 16/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 9.3778e-04 - mse: 9.3778e-04
# Epoch 16: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 39ms/step - loss: 9.3777e-04 - mse: 9.3777e-04 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 17/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 9.2911e-04 - mse: 9.2911e-04
# Epoch 17: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 115s 40ms/step - loss: 9.2909e-04 - mse: 9.2909e-04 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 18/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.8742e-04 - mse: 8.8742e-04
# Epoch 18: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 136s 38ms/step - loss: 8.8741e-04 - mse: 8.8741e-04 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 19/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.5643e-04 - mse: 8.5643e-04
# Epoch 19: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 38ms/step - loss: 8.5642e-04 - mse: 8.5642e-04 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 20/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 8.3500e-04 - mse: 8.3500e-04
# Epoch 20: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 112s 39ms/step - loss: 8.3500e-04 - mse: 8.3500e-04 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 21/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.9216e-04 - mse: 7.9216e-04
# Epoch 21: val_loss did not improve from 0.00803
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 113s 39ms/step - loss: 7.9216e-04 - mse: 7.9216e-04 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 21: early stopping
# ---Training time: 2747.23074937 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
#   23/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(32, 2400))
#   warnings.warn(msg)
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 24s 8ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(None, 2400))
#   warnings.warn(msg)
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step
# R2 scores: Train (SS) - 0.97233
# R2 scores: Validation (SS) - 0.67805
# R2 scores: Testing (SS) - -0.16515
# RMSE scores: Train (SS) - 0.02712
# RMSE scores: Validation (SS) - 0.10677
# RMSE scores: Testing (SS) - 0.19894

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
