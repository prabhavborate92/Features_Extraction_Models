# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
# tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Entire_Signal/CNN_With_Spectra/CNN_Models/Hyperparameter_Tuning_CNN_spectra/Model_7/Input_Output_Data_Model_7.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132106, 300, 1)
# Target shape (SS), Y =  (132106,)
# After reshaping, X =  (132106, 300)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92473, 300)
# Validation samples: (13211, 300)
# Testing samples: (26422, 300)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(256,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        77,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │         1,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,561 (369.38 KB)
#  Trainable params: 94,561 (369.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0305 - mse: 0.0305
# Epoch 1: val_loss improved from inf to 0.02116, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 0.0304 - mse: 0.0304 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 2/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 2: val_loss improved from 0.02116 to 0.01659, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0166 - val_mse: 0.0166
# Epoch 3/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - mse: 0.0040
# Epoch 3: val_loss improved from 0.01659 to 0.01413, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 4/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 4: val_loss improved from 0.01413 to 0.01284, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 5/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 5: val_loss did not improve from 0.01284
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 6/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 6: val_loss improved from 0.01284 to 0.01282, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 7/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 7: val_loss did not improve from 0.01282
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0172 - val_mse: 0.0172
# Epoch 8/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 8: val_loss improved from 0.01282 to 0.01242, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 9/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 9: val_loss did not improve from 0.01242
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 10/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 10: val_loss did not improve from 0.01242
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 11/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 11: val_loss did not improve from 0.01242
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 12/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 12: val_loss did not improve from 0.01242
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 13/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 13: val_loss did not improve from 0.01242
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 14/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 14: val_loss did not improve from 0.01242
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 22s 4ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 15/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 15: val_loss did not improve from 0.01242
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 16/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 16: val_loss did not improve from 0.01242
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 17/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 17: val_loss improved from 0.01242 to 0.01114, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 18/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 18: val_loss did not improve from 0.01114
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 19/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 19: val_loss did not improve from 0.01114
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 20/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 20: val_loss did not improve from 0.01114
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 21/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 21: val_loss did not improve from 0.01114
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 22/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 22: val_loss did not improve from 0.01114
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 23/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 23: val_loss did not improve from 0.01114
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 24/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 24: val_loss did not improve from 0.01114
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 25/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 25: val_loss did not improve from 0.01114
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 22s 4ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 26/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 26: val_loss improved from 0.01114 to 0.01090, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 27/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 27: val_loss did not improve from 0.01090
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 28/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 28: val_loss improved from 0.01090 to 0.01058, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 29/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 29: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 30/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 30: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 31/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 31: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 32/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 32: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 33/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 33: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 34/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 34: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 35/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 35: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 36/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 36: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 37/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 37: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 38/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 38: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 39/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 39: val_loss did not improve from 0.01058
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 40/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 40: val_loss improved from 0.01058 to 0.01054, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 41/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 41: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 42/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 42: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 43/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 43: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 44/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 44: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 45/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 45: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 46/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 46: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 47/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 47: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 48/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 48: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 49/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 49: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 50/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 50: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 51/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 51: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 52/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 52: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 53/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 53: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 54/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 54: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 55/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 55: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 56/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 56: val_loss did not improve from 0.01054
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 57/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 57: val_loss improved from 0.01054 to 0.01051, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 58/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 58: val_loss did not improve from 0.01051
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 59/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 59: val_loss did not improve from 0.01051
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 60/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 60: val_loss did not improve from 0.01051
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 61/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 61: val_loss did not improve from 0.01051
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 62/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 62: val_loss did not improve from 0.01051
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 63/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 63: val_loss did not improve from 0.01051
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 64/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 64: val_loss did not improve from 0.01051
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 65/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 65: val_loss improved from 0.01051 to 0.01044, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 66/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 66: val_loss improved from 0.01044 to 0.01041, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 67/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 67: val_loss did not improve from 0.01041
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 68/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 68: val_loss did not improve from 0.01041
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 69/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 69: val_loss did not improve from 0.01041
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 70/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 70: val_loss did not improve from 0.01041
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 71/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 71: val_loss did not improve from 0.01041
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 72/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 72: val_loss did not improve from 0.01041
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 73/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 73: val_loss did not improve from 0.01041
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 74/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 74: val_loss did not improve from 0.01041
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 75/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 75: val_loss did not improve from 0.01041
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 76/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 76: val_loss improved from 0.01041 to 0.01020, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 77/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 77: val_loss did not improve from 0.01020
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 78/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 78: val_loss did not improve from 0.01020
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 79/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 79: val_loss did not improve from 0.01020
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 80/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 80: val_loss did not improve from 0.01020
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 81/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 81: val_loss improved from 0.01020 to 0.01013, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 82/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 82: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 83/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 83: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 84/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 84: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 85/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 85: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 86/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 86: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 87/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 87: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 88/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 88: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 89/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 89: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 90/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 90: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 91/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 91: val_loss did not improve from 0.01013
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 92/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 92: val_loss improved from 0.01013 to 0.00999, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 93/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 93: val_loss did not improve from 0.00999
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 94/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 94: val_loss did not improve from 0.00999
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 95/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 95: val_loss did not improve from 0.00999
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 96/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 96: val_loss did not improve from 0.00999
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 97/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 97: val_loss did not improve from 0.00999
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 98/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 98: val_loss did not improve from 0.00999
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 99/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 99: val_loss did not improve from 0.00999
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 100/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 100: val_loss did not improve from 0.00999
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0122 - val_mse: 0.0122
# ---Training time: 1613.36244512 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
#  111/2890 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(32, 300))
#   warnings.warn(msg)
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(None, 300))
#   warnings.warn(msg)
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# R2 scores: Train (SS) - 0.94240
# R2 scores: Validation (SS) - 0.65566
# R2 scores: Testing (SS) - 0.53475
# RMSE scores: Train (SS) - 0.03912
# RMSE scores: Validation (SS) - 0.11042
# RMSE scores: Testing (SS) - 0.12571

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
