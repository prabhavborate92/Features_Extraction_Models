# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
# tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Entire_Signal/CNN_With_Spectra/CNN_Models/Hyperparameter_Tuning_CNN_spectra/Model_3/Input_Output_Data_Model_3.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132106, 300, 1)
# Target shape (SS), Y =  (132106,)
# After reshaping, X =  (132106, 300)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92473, 300)
# Validation samples: (13211, 300)
# Testing samples: (26422, 300)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(256,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        77,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │         1,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,561 (369.38 KB)
#  Trainable params: 94,561 (369.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0204 - mse: 0.0204
# Epoch 1: val_loss improved from inf to 0.00867, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 2/100
# 2872/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 2: val_loss improved from 0.00867 to 0.00649, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 3/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 3: val_loss did not improve from 0.00649
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 4/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 4: val_loss did not improve from 0.00649
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 5/100
# 2879/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 5: val_loss did not improve from 0.00649
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 6/100
# 2873/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 6: val_loss did not improve from 0.00649
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 7/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 7: val_loss did not improve from 0.00649
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 8/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 8: val_loss did not improve from 0.00649
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 9/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 9: val_loss did not improve from 0.00649
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 10/100
# 2872/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 10: val_loss did not improve from 0.00649
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 11/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 11: val_loss did not improve from 0.00649
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 12/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 12: val_loss improved from 0.00649 to 0.00647, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 13/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 13: val_loss did not improve from 0.00647
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 14/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 14: val_loss did not improve from 0.00647
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 15/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 15: val_loss improved from 0.00647 to 0.00643, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 16/100
# 2872/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 16: val_loss did not improve from 0.00643
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 17/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 17: val_loss did not improve from 0.00643
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 18/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 18: val_loss improved from 0.00643 to 0.00628, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 19/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 19: val_loss improved from 0.00628 to 0.00625, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 20/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 20: val_loss improved from 0.00625 to 0.00606, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 21/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 21: val_loss did not improve from 0.00606
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 22/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 22: val_loss did not improve from 0.00606
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 23/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 23: val_loss did not improve from 0.00606
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 24/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 24: val_loss did not improve from 0.00606
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 25/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 25: val_loss improved from 0.00606 to 0.00584, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 26/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 26: val_loss did not improve from 0.00584
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 27/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 27: val_loss did not improve from 0.00584
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 28/100
# 2878/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 28: val_loss did not improve from 0.00584
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 29/100
# 2880/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 29: val_loss did not improve from 0.00584
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 30/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 30: val_loss did not improve from 0.00584
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 31/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 31: val_loss improved from 0.00584 to 0.00579, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 32/100
# 2882/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 32: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 33/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 33: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 34/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 34: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 35/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 35: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 36/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 36: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 37/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 37: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 38/100
# 2884/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 38: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 39/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 39: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 40/100
# 2875/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 40: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 41/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 41: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 42/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 42: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 43/100
# 2881/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 43: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 44/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 44: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 45/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 45: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 46/100
# 2874/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 46: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 47/100
# 2872/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 47: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 48/100
# 2883/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 48: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 49/100
# 2877/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 49: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 50/100
# 2876/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 50: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 51/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 51: val_loss did not improve from 0.00579
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 51: early stopping
# ---Training time: 594.87356377 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
#  130/2890 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(32, 300))
#   warnings.warn(msg)
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(None, 300))
#   warnings.warn(msg)
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# R2 scores: Train (SS) - 0.95376
# R2 scores: Validation (SS) - 0.82516
# R2 scores: Testing (SS) - -0.09074
# RMSE scores: Train (SS) - 0.03505
# RMSE scores: Validation (SS) - 0.07868
# RMSE scores: Testing (SS) - 0.19249

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
