# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
# tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Entire_Signal/CNN_With_Spectra/CNN_Models/Hyperparameter_Tuning_CNN_spectra/Model_6/Input_Output_Data_Model_6.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten(), 'F3':data1['F3'].flatten(), 'F4':data1['F4'].flatten(), 'F5':data1['F5'].flatten(),
                   'F6':data1['F6'].flatten(), 'F7':data1['F7'].flatten(), 'F8':data1['F8'].flatten(),'SS':data1['SS'].flatten()})
df = df[['F1','F2','F3','F4','F5','F6','F7','F8','SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132106, 300, 8)
# Target shape (SS), Y =  (132106,)
# After reshaping, X =  (132106, 2400)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92473, 2400)
# Validation samples: (13211, 2400)
# Testing samples: (26422, 2400)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(2400,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(1024,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(256,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(64, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 2400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     2,458,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,737,537 (10.44 MB)
#  Trainable params: 2,737,537 (10.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0204 - mse: 0.0204
# Epoch 1: val_loss improved from inf to 0.01786, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 126s 43ms/step - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 2/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 2: val_loss improved from 0.01786 to 0.00921, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 125s 37ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 3/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 3: val_loss did not improve from 0.00921
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 106s 37ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 4/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 4: val_loss did not improve from 0.00921
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 145s 38ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 5/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 5: val_loss improved from 0.00921 to 0.00917, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check1.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 146s 39ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 6/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 6: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 138s 38ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 7/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 7: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 144s 38ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 8/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 8: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 106s 37ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 9/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 9: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 146s 38ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 10/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 10: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 143s 38ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 11/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 9.9397e-04 - mse: 9.9397e-04
# Epoch 11: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 110s 38ms/step - loss: 9.9392e-04 - mse: 9.9392e-04 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 12/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 9.2593e-04 - mse: 9.2593e-04
# Epoch 12: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 109s 38ms/step - loss: 9.2592e-04 - mse: 9.2592e-04 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 13/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.5192e-04 - mse: 8.5192e-04
# Epoch 13: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 38ms/step - loss: 8.5190e-04 - mse: 8.5190e-04 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 14/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.4620e-04 - mse: 8.4620e-04
# Epoch 14: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 38ms/step - loss: 8.4616e-04 - mse: 8.4616e-04 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 15/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.0050e-04 - mse: 8.0050e-04
# Epoch 15: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 141s 38ms/step - loss: 8.0048e-04 - mse: 8.0048e-04 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 16/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.7561e-04 - mse: 7.7561e-04
# Epoch 16: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 145s 39ms/step - loss: 7.7558e-04 - mse: 7.7558e-04 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 17/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.3594e-04 - mse: 7.3594e-04
# Epoch 17: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 141s 38ms/step - loss: 7.3592e-04 - mse: 7.3592e-04 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 18/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.1738e-04 - mse: 7.1738e-04
# Epoch 18: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 107s 37ms/step - loss: 7.1737e-04 - mse: 7.1737e-04 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 19/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.8672e-04 - mse: 6.8672e-04
# Epoch 19: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 145s 38ms/step - loss: 6.8671e-04 - mse: 6.8671e-04 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 20/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.8557e-04 - mse: 6.8557e-04
# Epoch 20: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 139s 37ms/step - loss: 6.8555e-04 - mse: 6.8555e-04 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 21/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.5767e-04 - mse: 6.5767e-04
# Epoch 21: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 143s 37ms/step - loss: 6.5767e-04 - mse: 6.5767e-04 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 22/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.5040e-04 - mse: 6.5040e-04
# Epoch 22: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - loss: 6.5039e-04 - mse: 6.5039e-04 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 23/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.3902e-04 - mse: 6.3902e-04
# Epoch 23: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 143s 38ms/step - loss: 6.3900e-04 - mse: 6.3900e-04 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 24/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.2103e-04 - mse: 6.2103e-04
# Epoch 24: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 110s 38ms/step - loss: 6.2103e-04 - mse: 6.2103e-04 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 25/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.1992e-04 - mse: 6.1992e-04
# Epoch 25: val_loss did not improve from 0.00917
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 142s 38ms/step - loss: 6.1991e-04 - mse: 6.1991e-04 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 25: early stopping
# ---Training time: 3328.48225474 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
#   10/2890 ━━━━━━━━━━━━━━━━━━━━ 34s 12ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(32, 2400))
#   warnings.warn(msg)
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 23s 8ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['X_train']
# Received: inputs=Tensor(shape=(None, 2400))
#   warnings.warn(msg)
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step
# R2 scores: Train (SS) - 0.97633
# R2 scores: Validation (SS) - 0.66290
# R2 scores: Testing (SS) - 0.27857
# RMSE scores: Train (SS) - 0.02508
# RMSE scores: Validation (SS) - 0.10925
# RMSE scores: Testing (SS) - 0.15655

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
