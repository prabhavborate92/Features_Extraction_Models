# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/CNN/Raw_Time_WFs/Hyperparameter_Tuning_Raw_WFs/Model_JGR_MLC_Ablmation_Study/CNN_Atten/Hyperparameter_Tuning/Model_4/Input_Output_Data_CNN_Attn.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten(), 'F3':data1['F3'].flatten(), 'F4':data1['F4'].flatten(), 'F5':data1['F5'].flatten(),'F6':data1['F6'].flatten(), 'F7':data1['F7'].flatten(), 'F8':data1['F8'].flatten(), 'F9':data1['F9'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 9)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 2700)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 2700)
# Validation samples: (13208, 2700)
# Testing samples: (26416, 2700)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(2700,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 2700)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,382,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,452,737 (5.54 MB)
#  Trainable params: 1,452,737 (5.54 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0131 - mse: 0.0131
# Epoch 1: val_loss improved from None to 0.02240, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 68s 23ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0224 - val_mse: 0.0224
# Epoch 2/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 2: val_loss improved from 0.02240 to 0.02228, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 65s 22ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 3/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 3: val_loss improved from 0.02228 to 0.01673, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 4/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 4: val_loss improved from 0.01673 to 0.01077, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 62s 21ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 5/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 5: val_loss improved from 0.01077 to 0.00936, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 88s 24ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 6/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.8822e-04 - mse: 9.8822e-04
# Epoch 6: val_loss improved from 0.00936 to 0.00818, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 67s 23ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 7/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.8687e-04 - mse: 8.8687e-04
# Epoch 7: val_loss improved from 0.00818 to 0.00694, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 77s 22ms/step - loss: 9.1497e-04 - mse: 9.1497e-04 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 8/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.1187e-04 - mse: 9.1187e-04
# Epoch 8: val_loss did not improve from 0.00694
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 84s 22ms/step - loss: 8.7993e-04 - mse: 8.7993e-04 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 9/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.9720e-04 - mse: 7.9720e-04
# Epoch 9: val_loss improved from 0.00694 to 0.00599, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 65s 23ms/step - loss: 8.0326e-04 - mse: 8.0326e-04 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 10/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.6604e-04 - mse: 7.6604e-04
# Epoch 10: val_loss did not improve from 0.00599
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 63s 22ms/step - loss: 7.7229e-04 - mse: 7.7229e-04 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 11/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.1110e-04 - mse: 7.1110e-04
# Epoch 11: val_loss did not improve from 0.00599
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 63s 22ms/step - loss: 7.2503e-04 - mse: 7.2503e-04 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 12/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.8103e-04 - mse: 6.8103e-04
# Epoch 12: val_loss did not improve from 0.00599
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 65s 23ms/step - loss: 6.9049e-04 - mse: 6.9049e-04 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 13/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.4155e-04 - mse: 6.4155e-04
# Epoch 13: val_loss did not improve from 0.00599
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 80s 22ms/step - loss: 6.6580e-04 - mse: 6.6580e-04 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 14/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.0482e-04 - mse: 6.0482e-04
# Epoch 14: val_loss did not improve from 0.00599
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 22ms/step - loss: 6.3145e-04 - mse: 6.3145e-04 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 15/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.9308e-04 - mse: 5.9308e-04
# Epoch 15: val_loss did not improve from 0.00599
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 64s 22ms/step - loss: 6.1075e-04 - mse: 6.1075e-04 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 16/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.6648e-04 - mse: 5.6648e-04
# Epoch 16: val_loss improved from 0.00599 to 0.00593, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 22ms/step - loss: 5.8962e-04 - mse: 5.8962e-04 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 17/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.5510e-04 - mse: 5.5510e-04
# Epoch 17: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 63s 22ms/step - loss: 5.6957e-04 - mse: 5.6957e-04 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 18/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4213e-04 - mse: 5.4213e-04
# Epoch 18: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 85s 23ms/step - loss: 5.6053e-04 - mse: 5.6053e-04 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 19/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.2854e-04 - mse: 5.2854e-04
# Epoch 19: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 65s 22ms/step - loss: 5.3476e-04 - mse: 5.3476e-04 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 20/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.2928e-04 - mse: 5.2928e-04
# Epoch 20: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 22ms/step - loss: 5.3102e-04 - mse: 5.3102e-04 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 21/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.0658e-04 - mse: 5.0658e-04
# Epoch 21: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 65s 23ms/step - loss: 5.1117e-04 - mse: 5.1117e-04 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 22/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8969e-04 - mse: 4.8969e-04
# Epoch 22: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 63s 22ms/step - loss: 5.0082e-04 - mse: 5.0082e-04 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 23/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8246e-04 - mse: 4.8246e-04
# Epoch 23: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 63s 22ms/step - loss: 4.8343e-04 - mse: 4.8343e-04 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 24/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.7398e-04 - mse: 4.7398e-04
# Epoch 24: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 63s 22ms/step - loss: 4.8110e-04 - mse: 4.8110e-04 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 25/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6940e-04 - mse: 4.6940e-04
# Epoch 25: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 63s 22ms/step - loss: 4.7686e-04 - mse: 4.7686e-04 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 26/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.5389e-04 - mse: 4.5389e-04
# Epoch 26: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 67s 23ms/step - loss: 4.6153e-04 - mse: 4.6153e-04 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 27/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.5430e-04 - mse: 4.5430e-04
# Epoch 27: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 65s 22ms/step - loss: 4.5903e-04 - mse: 4.5903e-04 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 28/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.3936e-04 - mse: 4.3936e-04
# Epoch 28: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 66s 23ms/step - loss: 4.4876e-04 - mse: 4.4876e-04 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 29/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2751e-04 - mse: 4.2751e-04
# Epoch 29: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 64s 22ms/step - loss: 4.3198e-04 - mse: 4.3198e-04 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 30/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3163e-04 - mse: 4.3163e-04
# Epoch 30: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 22ms/step - loss: 4.3641e-04 - mse: 4.3641e-04 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 31/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2006e-04 - mse: 4.2006e-04
# Epoch 31: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 23ms/step - loss: 4.2568e-04 - mse: 4.2568e-04 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 32/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1769e-04 - mse: 4.1769e-04
# Epoch 32: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 64s 22ms/step - loss: 4.2441e-04 - mse: 4.2441e-04 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 33/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0770e-04 - mse: 4.0770e-04
# Epoch 33: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 65s 23ms/step - loss: 4.1523e-04 - mse: 4.1523e-04 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 34/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0341e-04 - mse: 4.0341e-04
# Epoch 34: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 23ms/step - loss: 4.1337e-04 - mse: 4.1337e-04 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 35/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9925e-04 - mse: 3.9925e-04
# Epoch 35: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 23ms/step - loss: 4.0752e-04 - mse: 4.0752e-04 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 36/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9368e-04 - mse: 3.9368e-04
# Epoch 36: val_loss did not improve from 0.00593
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 68s 24ms/step - loss: 4.0354e-04 - mse: 4.0354e-04 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 36: early stopping
# ---Training time: 2556.32172561 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# R2 scores: Train (SS) - 0.98465
# R2 scores: Validation (SS) - 0.82438
# R2 scores: Testing (SS) - 0.21977
# RMSE scores: Train (SS) - 0.02020
# RMSE scores: Validation (SS) - 0.07885
# RMSE scores: Testing (SS) - 0.16281
