# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/CNN/Raw_Time_WFs/Hyperparameter_Tuning_Raw_WFs/Model_JGR_MLC_Ablmation_Study/CNN_Atten/Hyperparameter_Tuning/Model_3/Input_Output_Data_CNN_Attn.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten(), 'F3':data1['F3'].flatten(), 'F4':data1['F4'].flatten(), 'F5':data1['F5'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1', 'F2', 'F3', 'F4', 'F5', 'SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 5)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 1500)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 1500)
# Validation samples: (13208, 1500)
# Testing samples: (26416, 1500)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(1500,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 1500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       768,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 838,337 (3.20 MB)
#  Trainable params: 838,337 (3.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0119 - mse: 0.0119
# Epoch 1: val_loss improved from None to 0.01951, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 48s 16ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 2/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 2: val_loss improved from 0.01951 to 0.01061, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 3/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 3: val_loss improved from 0.01061 to 0.00698, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 4/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.6236e-04 - mse: 9.6236e-04
# Epoch 4: val_loss improved from 0.00698 to 0.00544, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 9.1183e-04 - mse: 9.1183e-04 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 5/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.9203e-04 - mse: 7.9203e-04
# Epoch 5: val_loss did not improve from 0.00544
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 7.7089e-04 - mse: 7.7089e-04 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 6/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.1003e-04 - mse: 7.1003e-04
# Epoch 6: val_loss improved from 0.00544 to 0.00492, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 6.8769e-04 - mse: 6.8769e-04 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 7/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3336e-04 - mse: 6.3336e-04
# Epoch 7: val_loss did not improve from 0.00492
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - loss: 6.1517e-04 - mse: 6.1517e-04 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 8/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.7976e-04 - mse: 5.7976e-04
# Epoch 8: val_loss improved from 0.00492 to 0.00462, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 5.7084e-04 - mse: 5.7084e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 9/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.5950e-04 - mse: 5.5950e-04
# Epoch 9: val_loss did not improve from 0.00462
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 5.4897e-04 - mse: 5.4897e-04 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 10/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2231e-04 - mse: 5.2231e-04
# Epoch 10: val_loss improved from 0.00462 to 0.00462, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 5.1046e-04 - mse: 5.1046e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 11/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9775e-04 - mse: 4.9775e-04
# Epoch 11: val_loss improved from 0.00462 to 0.00434, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 4.8943e-04 - mse: 4.8943e-04 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 12/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.7038e-04 - mse: 4.7038e-04
# Epoch 12: val_loss improved from 0.00434 to 0.00427, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 14ms/step - loss: 4.6473e-04 - mse: 4.6473e-04 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 13/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5796e-04 - mse: 4.5796e-04
# Epoch 13: val_loss improved from 0.00427 to 0.00414, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 4.5110e-04 - mse: 4.5110e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 14/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3467e-04 - mse: 4.3467e-04
# Epoch 14: val_loss improved from 0.00414 to 0.00384, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 14ms/step - loss: 4.3391e-04 - mse: 4.3391e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 15/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1373e-04 - mse: 4.1373e-04
# Epoch 15: val_loss improved from 0.00384 to 0.00359, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 4.0954e-04 - mse: 4.0954e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 16/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0294e-04 - mse: 4.0294e-04
# Epoch 16: val_loss did not improve from 0.00359
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 3.9747e-04 - mse: 3.9747e-04 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 17/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8526e-04 - mse: 3.8526e-04
# Epoch 17: val_loss improved from 0.00359 to 0.00345, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 17: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 3.8498e-04 - mse: 3.8498e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 18/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7550e-04 - mse: 3.7550e-04
# Epoch 18: val_loss did not improve from 0.00345
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 3.6931e-04 - mse: 3.6931e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 19/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6264e-04 - mse: 3.6264e-04
# Epoch 19: val_loss did not improve from 0.00345
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 3.6134e-04 - mse: 3.6134e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 20/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4502e-04 - mse: 3.4502e-04
# Epoch 20: val_loss improved from 0.00345 to 0.00325, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 20: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 3.4900e-04 - mse: 3.4900e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 21/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3908e-04 - mse: 3.3908e-04
# Epoch 21: val_loss did not improve from 0.00325
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 3.4600e-04 - mse: 3.4600e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 22/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3296e-04 - mse: 3.3296e-04
# Epoch 22: val_loss improved from 0.00325 to 0.00299, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 22: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 3.3508e-04 - mse: 3.3508e-04 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 23/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2282e-04 - mse: 3.2282e-04
# Epoch 23: val_loss did not improve from 0.00299
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 3.2635e-04 - mse: 3.2635e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 24/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2102e-04 - mse: 3.2102e-04
# Epoch 24: val_loss did not improve from 0.00299
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 3.2271e-04 - mse: 3.2271e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 25/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0733e-04 - mse: 3.0733e-04
# Epoch 25: val_loss did not improve from 0.00299
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 3.1051e-04 - mse: 3.1051e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 26/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1042e-04 - mse: 3.1042e-04
# Epoch 26: val_loss did not improve from 0.00299
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 3.0647e-04 - mse: 3.0647e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 27/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9449e-04 - mse: 2.9449e-04
# Epoch 27: val_loss improved from 0.00299 to 0.00279, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 27: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - loss: 3.0067e-04 - mse: 3.0067e-04 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 28/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9543e-04 - mse: 2.9543e-04
# Epoch 28: val_loss improved from 0.00279 to 0.00276, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 28: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 2.9318e-04 - mse: 2.9318e-04 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 29/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9065e-04 - mse: 2.9065e-04
# Epoch 29: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - loss: 2.9362e-04 - mse: 2.9362e-04 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 30/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7992e-04 - mse: 2.7992e-04
# Epoch 30: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 2.8167e-04 - mse: 2.8167e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 31/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8307e-04 - mse: 2.8307e-04
# Epoch 31: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 14ms/step - loss: 2.8082e-04 - mse: 2.8082e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 32/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7683e-04 - mse: 2.7683e-04
# Epoch 32: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 2.7827e-04 - mse: 2.7827e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 33/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7456e-04 - mse: 2.7456e-04
# Epoch 33: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 2.7031e-04 - mse: 2.7031e-04 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 34/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7446e-04 - mse: 2.7446e-04
# Epoch 34: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 2.6619e-04 - mse: 2.6619e-04 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 35/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6527e-04 - mse: 2.6527e-04
# Epoch 35: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 2.6135e-04 - mse: 2.6135e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 36/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7291e-04 - mse: 2.7291e-04
# Epoch 36: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 2.6537e-04 - mse: 2.6537e-04 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 37/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5617e-04 - mse: 2.5617e-04
# Epoch 37: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 14ms/step - loss: 2.5212e-04 - mse: 2.5212e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 38/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6276e-04 - mse: 2.6276e-04
# Epoch 38: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 2.5965e-04 - mse: 2.5965e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 39/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4975e-04 - mse: 2.4975e-04
# Epoch 39: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 2.4924e-04 - mse: 2.4924e-04 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 40/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5614e-04 - mse: 2.5614e-04
# Epoch 40: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - loss: 2.5047e-04 - mse: 2.5047e-04 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 41/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5146e-04 - mse: 2.5146e-04
# Epoch 41: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 2.4548e-04 - mse: 2.4548e-04 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 42/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4170e-04 - mse: 2.4170e-04
# Epoch 42: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 2.4252e-04 - mse: 2.4252e-04 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 43/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3849e-04 - mse: 2.3849e-04
# Epoch 43: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 2.3968e-04 - mse: 2.3968e-04 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 44/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4139e-04 - mse: 2.4139e-04
# Epoch 44: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 2.3798e-04 - mse: 2.3798e-04 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 45/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3430e-04 - mse: 2.3430e-04
# Epoch 45: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 2.3634e-04 - mse: 2.3634e-04 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 46/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3599e-04 - mse: 2.3599e-04
# Epoch 46: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 14ms/step - loss: 2.3714e-04 - mse: 2.3714e-04 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 47/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3098e-04 - mse: 2.3098e-04
# Epoch 47: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 2.2968e-04 - mse: 2.2968e-04 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 48/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3274e-04 - mse: 2.3274e-04
# Epoch 48: val_loss did not improve from 0.00276
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 2.3237e-04 - mse: 2.3237e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 48: early stopping
# ---Training time: 2138.48170733 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# R2 scores: Train (SS) - 0.98869
# R2 scores: Validation (SS) - 0.88796
# R2 scores: Testing (SS) - 0.58478
# RMSE scores: Train (SS) - 0.01733
# RMSE scores: Validation (SS) - 0.06298
# RMSE scores: Testing (SS) - 0.11877
