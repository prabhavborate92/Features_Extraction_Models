# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(20)
tf.random.set_seed(20)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/CNN/Raw_Time_WFs/Hyperparameter_Tuning_Raw_WFs/Model_JGR_MLC_Ablmation_Study/CNN_Attn_LSTM_Conct/Try_3/Input_Output_Data_CNN_Attn_LSTM_Conct.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten(), 'F3':data1['F3'].flatten(), 'F4':data1['F4'].flatten(), 'F5':data1['F5'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1', 'F2', 'F3', 'F4', 'F5', 'SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 5)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 1500)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 1500)
# Validation samples: (13208, 1500)
# Testing samples: (26416, 1500)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(1500,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 1500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       768,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 838,337 (3.20 MB)
#  Trainable params: 838,337 (3.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0133 - mse: 0.0133
# Epoch 1: val_loss improved from None to 0.00428, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 48s 16ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 2/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 2: val_loss improved from 0.00428 to 0.00332, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 75s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 3/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 3: val_loss did not improve from 0.00332
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 4/100
# 2885/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 4: val_loss did not improve from 0.00332
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 5/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 5: val_loss improved from 0.00332 to 0.00301, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 6/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 6: val_loss improved from 0.00301 to 0.00288, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 7/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 7: val_loss did not improve from 0.00288
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 8/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 8: val_loss improved from 0.00288 to 0.00269, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 9/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.6059e-04 - mse: 9.6059e-04
# Epoch 9: val_loss improved from 0.00269 to 0.00248, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 9.7697e-04 - mse: 9.7697e-04 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 10/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.2464e-04 - mse: 9.2464e-04
# Epoch 10: val_loss improved from 0.00248 to 0.00226, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 9.3566e-04 - mse: 9.3566e-04 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 11/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.8645e-04 - mse: 8.8645e-04
# Epoch 11: val_loss did not improve from 0.00226
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 8.9512e-04 - mse: 8.9512e-04 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 12/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.5975e-04 - mse: 8.5975e-04
# Epoch 12: val_loss improved from 0.00226 to 0.00225, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 8.7658e-04 - mse: 8.7658e-04 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 13/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.2520e-04 - mse: 8.2520e-04
# Epoch 13: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 8.4522e-04 - mse: 8.4522e-04 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 14/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.1628e-04 - mse: 8.1628e-04
# Epoch 14: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 8.4219e-04 - mse: 8.4219e-04 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 15/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.9138e-04 - mse: 7.9138e-04
# Epoch 15: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 14ms/step - loss: 8.2189e-04 - mse: 8.2189e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 16/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.8247e-04 - mse: 7.8247e-04
# Epoch 16: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 8.0487e-04 - mse: 8.0487e-04 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 17/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7803e-04 - mse: 7.7803e-04
# Epoch 17: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 7.8889e-04 - mse: 7.8889e-04 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 18/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.6119e-04 - mse: 7.6119e-04
# Epoch 18: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 43s 14ms/step - loss: 7.7197e-04 - mse: 7.7197e-04 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 19/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.4443e-04 - mse: 7.4443e-04
# Epoch 19: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 14ms/step - loss: 7.5520e-04 - mse: 7.5520e-04 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 20/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.2373e-04 - mse: 7.2373e-04
# Epoch 20: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 7.3962e-04 - mse: 7.3962e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 21/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.1830e-04 - mse: 7.1830e-04
# Epoch 21: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 15ms/step - loss: 7.2549e-04 - mse: 7.2549e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 22/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.1840e-04 - mse: 7.1840e-04
# Epoch 22: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 80s 14ms/step - loss: 7.2259e-04 - mse: 7.2259e-04 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 23/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.2184e-04 - mse: 7.2184e-04
# Epoch 23: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 7.2283e-04 - mse: 7.2283e-04 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 24/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.9057e-04 - mse: 6.9057e-04
# Epoch 24: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 6.9572e-04 - mse: 6.9572e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 25/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.8792e-04 - mse: 6.8792e-04
# Epoch 25: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 6.8425e-04 - mse: 6.8425e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 26/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6531e-04 - mse: 6.6531e-04
# Epoch 26: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 14ms/step - loss: 6.7625e-04 - mse: 6.7625e-04 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 27/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.7097e-04 - mse: 6.7097e-04
# Epoch 27: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 6.7528e-04 - mse: 6.7528e-04 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 28/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.6238e-04 - mse: 6.6238e-04
# Epoch 28: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 6.6789e-04 - mse: 6.6789e-04 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 29/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.7674e-04 - mse: 6.7674e-04
# Epoch 29: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 6.6992e-04 - mse: 6.6992e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 30/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.5233e-04 - mse: 6.5233e-04
# Epoch 30: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 14ms/step - loss: 6.5479e-04 - mse: 6.5479e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 31/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.4446e-04 - mse: 6.4446e-04
# Epoch 31: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 6.4935e-04 - mse: 6.4935e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 32/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.6638e-04 - mse: 6.6638e-04
# Epoch 32: val_loss did not improve from 0.00225
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 6.6102e-04 - mse: 6.6102e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 32: early stopping
# ---Training time: 1559.11898208 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# R2 scores: Train (SS) - 0.98048
# R2 scores: Validation (SS) - 0.90712
# R2 scores: Testing (SS) - 0.74497
# RMSE scores: Train (SS) - 0.02278
# RMSE scores: Validation (SS) - 0.05734
# RMSE scores: Testing (SS) - 0.09308

# %%
# # Inverse scaling: SS
# Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
# Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
# y_test_SS = scaler_ss.inverse_transform(y_test_SS)
# y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
# y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
# y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# # Extract Data
# # SS
# savetxt('Y_train_SS.csv', Y_train_SS, delimiter=',')
# savetxt('Y_val_SS.csv', Y_val_SS, delimiter=',')
# savetxt('y_test_SS.csv', y_test_SS, delimiter=',')
# savetxt('y_predtrain_SS.csv', y_predtrain_SS, delimiter=',')
# savetxt('y_predval_SS.csv', y_predval_SS, delimiter=',')
# savetxt('y_predtest_SS.csv', y_predtest_SS, delimiter=',')

# %%
# # Download Data
# # SS
# files.download('Y_train_SS.csv')
# files.download('Y_val_SS.csv')
# files.download('y_test_SS.csv')
# files.download('y_predtrain_SS.csv')
# files.download('y_predval_SS.csv')
# files.download('y_predtest_SS.csv')
