# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/CNN/Raw_Time_WFs/Hyperparameter_Tuning_Raw_WFs/Model_JGR_MLC_Ablmation_Study/CNN_Attn_LSTM_Conct/Hyperparameter_Tuning/Model_5/Input_Output_Data_CNN_Attn_LSTM_Conct.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten(), 'F3':data1['F3'].flatten(), 'F4':data1['F4'].flatten(), 'F5':data1['F5'].flatten(), 'F6':data1['F6'].flatten(), 'F7':data1['F7'].flatten(), 'F8':data1['F8'].flatten(), 'F9':data1['F9'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 9)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 2700)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 2700)
# Validation samples: (13208, 2700)
# Testing samples: (26416, 2700)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(2700,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 2700)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,382,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,452,737 (5.54 MB)
#  Trainable params: 1,452,737 (5.54 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0129 - mse: 0.0129
# Epoch 1: val_loss improved from None to 0.01972, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 57s 19ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0197 - val_mse: 0.0197
# Epoch 2/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 2: val_loss improved from 0.01972 to 0.01204, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 75s 17ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 3/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 3: val_loss improved from 0.01204 to 0.00699, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 17ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 4/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 4: val_loss improved from 0.00699 to 0.00687, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 49s 17ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 5/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 5: val_loss improved from 0.00687 to 0.00630, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 17ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 6/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 6: val_loss did not improve from 0.00630
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 7/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 7: val_loss improved from 0.00630 to 0.00586, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 8/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 8: val_loss did not improve from 0.00586
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 9/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 9: val_loss improved from 0.00586 to 0.00576, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 10/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 10: val_loss did not improve from 0.00576
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 11/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 11: val_loss did not improve from 0.00576
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 12/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 12: val_loss did not improve from 0.00576
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 13/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 13: val_loss did not improve from 0.00576
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 17ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 14/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 14: val_loss improved from 0.00576 to 0.00534, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 15/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 15: val_loss improved from 0.00534 to 0.00503, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 16/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 16: val_loss improved from 0.00503 to 0.00462, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 17/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 17: val_loss did not improve from 0.00462
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 18/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 18: val_loss did not improve from 0.00462
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 19/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 19: val_loss did not improve from 0.00462
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 20/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 20: val_loss did not improve from 0.00462
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 21/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 21: val_loss did not improve from 0.00462
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 22/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 22: val_loss improved from 0.00462 to 0.00460, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 22: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 17ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 23/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 23: val_loss improved from 0.00460 to 0.00456, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 23: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 17ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 24/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 24: val_loss improved from 0.00456 to 0.00447, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 24: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 25/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 25: val_loss did not improve from 0.00447
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 26/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 26: val_loss improved from 0.00447 to 0.00436, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 26: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 84s 18ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 27/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 27: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 28/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 28: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 29/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.9698e-04 - mse: 9.9698e-04
# Epoch 29: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 18ms/step - loss: 9.9683e-04 - mse: 9.9683e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 30/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8897e-04 - mse: 9.8897e-04
# Epoch 30: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 17ms/step - loss: 9.8913e-04 - mse: 9.8913e-04 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 31/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.9860e-04 - mse: 9.9860e-04
# Epoch 31: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 9.8911e-04 - mse: 9.8911e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 32/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7383e-04 - mse: 9.7383e-04
# Epoch 32: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 18ms/step - loss: 9.7728e-04 - mse: 9.7728e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 33/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8690e-04 - mse: 9.8690e-04
# Epoch 33: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 9.8632e-04 - mse: 9.8632e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 34/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.6982e-04 - mse: 9.6982e-04
# Epoch 34: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 18ms/step - loss: 9.6602e-04 - mse: 9.6602e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 35/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.6867e-04 - mse: 9.6867e-04
# Epoch 35: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 9.6781e-04 - mse: 9.6781e-04 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 36/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7005e-04 - mse: 9.7005e-04
# Epoch 36: val_loss did not improve from 0.00436
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 17ms/step - loss: 9.6641e-04 - mse: 9.6641e-04 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 37/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.5006e-04 - mse: 9.5006e-04
# Epoch 37: val_loss improved from 0.00436 to 0.00416, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 37: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 18ms/step - loss: 9.5229e-04 - mse: 9.5229e-04 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 38/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4781e-04 - mse: 9.4781e-04
# Epoch 38: val_loss improved from 0.00416 to 0.00407, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 38: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 9.5166e-04 - mse: 9.5166e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 39/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.5589e-04 - mse: 9.5589e-04
# Epoch 39: val_loss improved from 0.00407 to 0.00405, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 39: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 9.4953e-04 - mse: 9.4953e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 40/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3229e-04 - mse: 9.3229e-04
# Epoch 40: val_loss did not improve from 0.00405
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 18ms/step - loss: 9.3163e-04 - mse: 9.3163e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 41/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3001e-04 - mse: 9.3001e-04
# Epoch 41: val_loss did not improve from 0.00405
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 17ms/step - loss: 9.2986e-04 - mse: 9.2986e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 42/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1477e-04 - mse: 9.1477e-04
# Epoch 42: val_loss did not improve from 0.00405
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 9.2119e-04 - mse: 9.2119e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 43/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2838e-04 - mse: 9.2838e-04
# Epoch 43: val_loss improved from 0.00405 to 0.00399, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 43: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 50s 17ms/step - loss: 9.2418e-04 - mse: 9.2418e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 44/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1763e-04 - mse: 9.1763e-04
# Epoch 44: val_loss did not improve from 0.00399
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 18ms/step - loss: 9.2424e-04 - mse: 9.2424e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 45/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.0016e-04 - mse: 9.0016e-04
# Epoch 45: val_loss improved from 0.00399 to 0.00396, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 45: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 55s 19ms/step - loss: 9.1226e-04 - mse: 9.1226e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 46/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.0676e-04 - mse: 9.0676e-04
# Epoch 46: val_loss did not improve from 0.00396
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 78s 18ms/step - loss: 9.1472e-04 - mse: 9.1472e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 47/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.9534e-04 - mse: 8.9534e-04
# Epoch 47: val_loss improved from 0.00396 to 0.00380, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 47: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 54s 19ms/step - loss: 9.0335e-04 - mse: 9.0335e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 48/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8789e-04 - mse: 8.8789e-04
# Epoch 48: val_loss did not improve from 0.00380
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 8.9216e-04 - mse: 8.9216e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 49/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.9284e-04 - mse: 8.9284e-04
# Epoch 49: val_loss did not improve from 0.00380
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 8.9469e-04 - mse: 8.9469e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 50/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9064e-04 - mse: 8.9064e-04
# Epoch 50: val_loss did not improve from 0.00380
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 18ms/step - loss: 8.9575e-04 - mse: 8.9575e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 51/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9273e-04 - mse: 8.9273e-04
# Epoch 51: val_loss did not improve from 0.00380
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 80s 18ms/step - loss: 8.9122e-04 - mse: 8.9122e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 52/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.8284e-04 - mse: 8.8284e-04
# Epoch 52: val_loss improved from 0.00380 to 0.00375, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 52: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 8.8563e-04 - mse: 8.8563e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 53/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8006e-04 - mse: 8.8006e-04
# Epoch 53: val_loss did not improve from 0.00375
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 8.8046e-04 - mse: 8.8046e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 54/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7243e-04 - mse: 8.7243e-04
# Epoch 54: val_loss did not improve from 0.00375
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 18ms/step - loss: 8.7321e-04 - mse: 8.7321e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 55/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7002e-04 - mse: 8.7002e-04
# Epoch 55: val_loss improved from 0.00375 to 0.00374, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 55: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 8.6937e-04 - mse: 8.6937e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 56/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7342e-04 - mse: 8.7342e-04
# Epoch 56: val_loss did not improve from 0.00374
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 80s 18ms/step - loss: 8.7732e-04 - mse: 8.7732e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 57/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.6899e-04 - mse: 8.6899e-04
# Epoch 57: val_loss improved from 0.00374 to 0.00368, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 57: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 8.6505e-04 - mse: 8.6505e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 58/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6161e-04 - mse: 8.6161e-04
# Epoch 58: val_loss did not improve from 0.00368
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 8.6579e-04 - mse: 8.6579e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 59/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.5852e-04 - mse: 8.5852e-04
# Epoch 59: val_loss did not improve from 0.00368
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 54s 19ms/step - loss: 8.6789e-04 - mse: 8.6789e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 60/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5128e-04 - mse: 8.5128e-04
# Epoch 60: val_loss did not improve from 0.00368
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 8.5497e-04 - mse: 8.5497e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 61/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6285e-04 - mse: 8.6285e-04
# Epoch 61: val_loss did not improve from 0.00368
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 18ms/step - loss: 8.5851e-04 - mse: 8.5851e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 62/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5198e-04 - mse: 8.5198e-04
# Epoch 62: val_loss did not improve from 0.00368
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 18ms/step - loss: 8.5143e-04 - mse: 8.5143e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 63/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.5162e-04 - mse: 8.5162e-04
# Epoch 63: val_loss did not improve from 0.00368
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 18ms/step - loss: 8.4957e-04 - mse: 8.4957e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 64/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5384e-04 - mse: 8.5384e-04
# Epoch 64: val_loss did not improve from 0.00368
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 8.4308e-04 - mse: 8.4308e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 65/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4084e-04 - mse: 8.4084e-04
# Epoch 65: val_loss improved from 0.00368 to 0.00365, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 65: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 18ms/step - loss: 8.4349e-04 - mse: 8.4349e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 66/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4000e-04 - mse: 8.4000e-04
# Epoch 66: val_loss did not improve from 0.00365
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 18ms/step - loss: 8.3711e-04 - mse: 8.3711e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 67/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4152e-04 - mse: 8.4152e-04
# Epoch 67: val_loss improved from 0.00365 to 0.00361, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 67: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 56s 19ms/step - loss: 8.3479e-04 - mse: 8.3479e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 68/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.4159e-04 - mse: 8.4159e-04
# Epoch 68: val_loss did not improve from 0.00361
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 8.4069e-04 - mse: 8.4069e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 69/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.3632e-04 - mse: 8.3632e-04
# Epoch 69: val_loss did not improve from 0.00361
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 8.3378e-04 - mse: 8.3378e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 70/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3412e-04 - mse: 8.3412e-04
# Epoch 70: val_loss improved from 0.00361 to 0.00358, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 70: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 8.3537e-04 - mse: 8.3537e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 71/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.2767e-04 - mse: 8.2767e-04
# Epoch 71: val_loss did not improve from 0.00358
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 8.2004e-04 - mse: 8.2004e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 72/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3005e-04 - mse: 8.3005e-04
# Epoch 72: val_loss did not improve from 0.00358
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 8.2310e-04 - mse: 8.2310e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 73/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.2597e-04 - mse: 8.2597e-04
# Epoch 73: val_loss did not improve from 0.00358
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 8.1242e-04 - mse: 8.1242e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 74/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2024e-04 - mse: 8.2024e-04
# Epoch 74: val_loss did not improve from 0.00358
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 8.1826e-04 - mse: 8.1826e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 75/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1671e-04 - mse: 8.1671e-04
# Epoch 75: val_loss did not improve from 0.00358
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 55s 19ms/step - loss: 8.1110e-04 - mse: 8.1110e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 76/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1616e-04 - mse: 8.1616e-04
# Epoch 76: val_loss improved from 0.00358 to 0.00348, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 76: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 51s 18ms/step - loss: 8.1004e-04 - mse: 8.1004e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 77/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1650e-04 - mse: 8.1650e-04
# Epoch 77: val_loss did not improve from 0.00348
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 18ms/step - loss: 8.1142e-04 - mse: 8.1142e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 78/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1606e-04 - mse: 8.1606e-04
# Epoch 78: val_loss improved from 0.00348 to 0.00345, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 78: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 8.0867e-04 - mse: 8.0867e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 79/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1254e-04 - mse: 8.1254e-04
# Epoch 79: val_loss did not improve from 0.00345
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 18ms/step - loss: 7.9989e-04 - mse: 7.9989e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 80/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.0126e-04 - mse: 8.0126e-04
# Epoch 80: val_loss improved from 0.00345 to 0.00340, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 80: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 54s 19ms/step - loss: 8.0044e-04 - mse: 8.0044e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 81/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0215e-04 - mse: 8.0215e-04
# Epoch 81: val_loss did not improve from 0.00340
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 7.9699e-04 - mse: 7.9699e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 82/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.1206e-04 - mse: 8.1206e-04
# Epoch 82: val_loss did not improve from 0.00340
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 18ms/step - loss: 8.0092e-04 - mse: 8.0092e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 83/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9547e-04 - mse: 7.9547e-04
# Epoch 83: val_loss did not improve from 0.00340
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 54s 19ms/step - loss: 7.9341e-04 - mse: 7.9341e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 84/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0003e-04 - mse: 8.0003e-04
# Epoch 84: val_loss did not improve from 0.00340
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 7.9669e-04 - mse: 7.9669e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 85/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9567e-04 - mse: 7.9567e-04
# Epoch 85: val_loss did not improve from 0.00340
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 18ms/step - loss: 7.8861e-04 - mse: 7.8861e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 86/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9146e-04 - mse: 7.9146e-04
# Epoch 86: val_loss did not improve from 0.00340
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 7.8646e-04 - mse: 7.8646e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 87/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9652e-04 - mse: 7.9652e-04
# Epoch 87: val_loss improved from 0.00340 to 0.00334, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 87: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 53s 18ms/step - loss: 7.9091e-04 - mse: 7.9091e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 88/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9353e-04 - mse: 7.9353e-04
# Epoch 88: val_loss improved from 0.00334 to 0.00327, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 88: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 19ms/step - loss: 7.8569e-04 - mse: 7.8569e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 89/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9298e-04 - mse: 7.9298e-04
# Epoch 89: val_loss did not improve from 0.00327
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 80s 18ms/step - loss: 7.8841e-04 - mse: 7.8841e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 90/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9778e-04 - mse: 7.9778e-04
# Epoch 90: val_loss did not improve from 0.00327
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 54s 19ms/step - loss: 7.8348e-04 - mse: 7.8348e-04 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 91/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9103e-04 - mse: 7.9103e-04
# Epoch 91: val_loss did not improve from 0.00327
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 7.8150e-04 - mse: 7.8150e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 92/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.0126e-04 - mse: 8.0126e-04
# Epoch 92: val_loss did not improve from 0.00327
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 54s 19ms/step - loss: 7.8342e-04 - mse: 7.8342e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 93/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7902e-04 - mse: 7.7902e-04
# Epoch 93: val_loss improved from 0.00327 to 0.00324, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 93: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 7.7208e-04 - mse: 7.7208e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 94/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.8288e-04 - mse: 7.8288e-04
# Epoch 94: val_loss did not improve from 0.00324
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 85s 19ms/step - loss: 7.7541e-04 - mse: 7.7541e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 95/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.8014e-04 - mse: 7.8014e-04
# Epoch 95: val_loss did not improve from 0.00324
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 82s 19ms/step - loss: 7.7153e-04 - mse: 7.7153e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 96/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7911e-04 - mse: 7.7911e-04
# Epoch 96: val_loss improved from 0.00324 to 0.00314, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 96: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 80s 18ms/step - loss: 7.6633e-04 - mse: 7.6633e-04 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 97/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7770e-04 - mse: 7.7770e-04
# Epoch 97: val_loss did not improve from 0.00314
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 81s 18ms/step - loss: 7.6473e-04 - mse: 7.6473e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 98/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7577e-04 - mse: 7.7577e-04
# Epoch 98: val_loss did not improve from 0.00314
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 18ms/step - loss: 7.6480e-04 - mse: 7.6480e-04 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 99/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7317e-04 - mse: 7.7317e-04
# Epoch 99: val_loss did not improve from 0.00314
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 83s 19ms/step - loss: 7.6621e-04 - mse: 7.6621e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 100/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.6713e-04 - mse: 7.6713e-04
# Epoch 100: val_loss did not improve from 0.00314
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 52s 18ms/step - loss: 7.5532e-04 - mse: 7.5532e-04 - val_loss: 0.0034 - val_mse: 0.0034
# ---Training time: 6327.89192414 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# R2 scores: Train (SS) - 0.97575
# R2 scores: Validation (SS) - 0.90475
# R2 scores: Testing (SS) - 0.66883
# RMSE scores: Train (SS) - 0.02538
# RMSE scores: Validation (SS) - 0.05807
# RMSE scores: Testing (SS) - 0.10607
