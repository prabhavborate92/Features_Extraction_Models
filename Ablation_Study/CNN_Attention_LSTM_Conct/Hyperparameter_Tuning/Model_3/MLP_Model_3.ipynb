# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/Final_Features_Extraction_Codes/CNN/Raw_Time_WFs/Hyperparameter_Tuning_Raw_WFs/Model_JGR_MLC_Ablmation_Study/CNN_Attn_LSTM_Conct/Hyperparameter_Tuning/Model_3/Input_Output_Data_CNN_Attn_LSTM_Conct.mat')
df = pd.DataFrame({'F1':data1['F1'].flatten(), 'F2':data1['F2'].flatten(), 'F3':data1['F3'].flatten(), 'F4':data1['F4'].flatten(), 'F5':data1['F5'].flatten(), 'SS':data1['SS'].flatten()})
df = df[['F1', 'F2', 'F3', 'F4', 'F5', 'SS']]

# %%
# Preprocessing (SS)
arr = df.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (132076, 300, 5)
# Target shape (SS), Y =  (132076,)
# After reshaping, X =  (132076, 1500)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (92452, 1500)
# Validation samples: (13208, 1500)
# Testing samples: (26416, 1500)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(1500,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 1500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       768,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 838,337 (3.20 MB)
#  Trainable params: 838,337 (3.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0151 - mse: 0.0151
# Epoch 1: val_loss improved from None to 0.00757, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 43s 14ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 2/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 2: val_loss improved from 0.00757 to 0.00669, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 14ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 3/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 3: val_loss improved from 0.00669 to 0.00536, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 4/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 4: val_loss did not improve from 0.00536
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 5/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 5: val_loss improved from 0.00536 to 0.00524, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 37s 13ms/step - loss: 9.7993e-04 - mse: 9.7993e-04 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 6/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.5952e-04 - mse: 9.5952e-04
# Epoch 6: val_loss improved from 0.00524 to 0.00508, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - loss: 9.1364e-04 - mse: 9.1364e-04 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 7/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.8688e-04 - mse: 8.8688e-04
# Epoch 7: val_loss improved from 0.00508 to 0.00477, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 8.5166e-04 - mse: 8.5166e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 8/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.4947e-04 - mse: 8.4947e-04
# Epoch 8: val_loss improved from 0.00477 to 0.00468, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 37s 13ms/step - loss: 7.9154e-04 - mse: 7.9154e-04 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 9/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.9639e-04 - mse: 7.9639e-04
# Epoch 9: val_loss did not improve from 0.00468
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 7.5865e-04 - mse: 7.5865e-04 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 10/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.8368e-04 - mse: 7.8368e-04
# Epoch 10: val_loss did not improve from 0.00468
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 7.4055e-04 - mse: 7.4055e-04 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 11/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.5659e-04 - mse: 7.5659e-04
# Epoch 11: val_loss did not improve from 0.00468
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 7.1071e-04 - mse: 7.1071e-04 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 12/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.3486e-04 - mse: 7.3486e-04
# Epoch 12: val_loss did not improve from 0.00468
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - loss: 6.8356e-04 - mse: 6.8356e-04 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 13/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.1788e-04 - mse: 7.1788e-04
# Epoch 13: val_loss did not improve from 0.00468
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - loss: 6.6167e-04 - mse: 6.6167e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 14/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.9349e-04 - mse: 6.9349e-04
# Epoch 14: val_loss improved from 0.00468 to 0.00408, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 6.5049e-04 - mse: 6.5049e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 15/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.5202e-04 - mse: 6.5202e-04
# Epoch 15: val_loss did not improve from 0.00408
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 6.2774e-04 - mse: 6.2774e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 16/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6193e-04 - mse: 6.6193e-04
# Epoch 16: val_loss improved from 0.00408 to 0.00407, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 6.2750e-04 - mse: 6.2750e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 17/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3276e-04 - mse: 6.3276e-04
# Epoch 17: val_loss did not improve from 0.00407
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 6.1115e-04 - mse: 6.1115e-04 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 18/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3758e-04 - mse: 6.3758e-04
# Epoch 18: val_loss improved from 0.00407 to 0.00378, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 6.1070e-04 - mse: 6.1070e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 19/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.1506e-04 - mse: 6.1506e-04
# Epoch 19: val_loss did not improve from 0.00378
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 5.9249e-04 - mse: 5.9249e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 20/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.0558e-04 - mse: 6.0558e-04
# Epoch 20: val_loss did not improve from 0.00378
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - loss: 5.7908e-04 - mse: 5.7908e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 21/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.0364e-04 - mse: 6.0364e-04
# Epoch 21: val_loss improved from 0.00378 to 0.00365, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - loss: 5.7462e-04 - mse: 5.7462e-04 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 22/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9244e-04 - mse: 5.9244e-04
# Epoch 22: val_loss did not improve from 0.00365
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 43s 14ms/step - loss: 5.6828e-04 - mse: 5.6828e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 23/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.8891e-04 - mse: 5.8891e-04
# Epoch 23: val_loss did not improve from 0.00365
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 5.5804e-04 - mse: 5.5804e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 24/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.7070e-04 - mse: 5.7070e-04
# Epoch 24: val_loss did not improve from 0.00365
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 5.4666e-04 - mse: 5.4666e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 25/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.7655e-04 - mse: 5.7655e-04
# Epoch 25: val_loss did not improve from 0.00365
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - loss: 5.4489e-04 - mse: 5.4489e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 26/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6268e-04 - mse: 5.6268e-04
# Epoch 26: val_loss did not improve from 0.00365
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 5.3145e-04 - mse: 5.3145e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 27/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.5824e-04 - mse: 5.5824e-04
# Epoch 27: val_loss did not improve from 0.00365
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 5.2559e-04 - mse: 5.2559e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 28/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.5107e-04 - mse: 5.5107e-04
# Epoch 28: val_loss did not improve from 0.00365
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 5.1988e-04 - mse: 5.1988e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 29/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4215e-04 - mse: 5.4215e-04
# Epoch 29: val_loss did not improve from 0.00365
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 5.1196e-04 - mse: 5.1196e-04 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 30/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.3428e-04 - mse: 5.3428e-04
# Epoch 30: val_loss improved from 0.00365 to 0.00343, saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
#
# Epoch 30: finished saving model to /content/drive/My Drive/Colab Notebooks/Entire_Signal/Automatic_Features_Extraction/New_AFE_Models/MLP_Model_With_Extracted_Features/Check.keras
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - loss: 5.0566e-04 - mse: 5.0566e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 31/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2034e-04 - mse: 5.2034e-04
# Epoch 31: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 4.9987e-04 - mse: 4.9987e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 32/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2205e-04 - mse: 5.2205e-04
# Epoch 32: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 4.9550e-04 - mse: 4.9550e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 33/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1176e-04 - mse: 5.1176e-04
# Epoch 33: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - loss: 4.8999e-04 - mse: 4.8999e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 34/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0963e-04 - mse: 5.0963e-04
# Epoch 34: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 4.8623e-04 - mse: 4.8623e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 35/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0078e-04 - mse: 5.0078e-04
# Epoch 35: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 14ms/step - loss: 4.7928e-04 - mse: 4.7928e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 36/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.9882e-04 - mse: 4.9882e-04
# Epoch 36: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 4.7603e-04 - mse: 4.7603e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 37/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.9700e-04 - mse: 4.9700e-04
# Epoch 37: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 4.7412e-04 - mse: 4.7412e-04 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 38/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8531e-04 - mse: 4.8531e-04
# Epoch 38: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - loss: 4.6609e-04 - mse: 4.6609e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 39/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8181e-04 - mse: 4.8181e-04
# Epoch 39: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 4.6209e-04 - mse: 4.6209e-04 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 40/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7410e-04 - mse: 4.7410e-04
# Epoch 40: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 4.5790e-04 - mse: 4.5790e-04 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 41/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7400e-04 - mse: 4.7400e-04
# Epoch 41: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 4.5381e-04 - mse: 4.5381e-04 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 42/100
# 2886/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6786e-04 - mse: 4.6786e-04
# Epoch 42: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 4.5070e-04 - mse: 4.5070e-04 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 43/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6901e-04 - mse: 4.6901e-04
# Epoch 43: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 4.5138e-04 - mse: 4.5138e-04 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 44/100
# 2887/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6120e-04 - mse: 4.6120e-04
# Epoch 44: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 4.4428e-04 - mse: 4.4428e-04 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 45/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6131e-04 - mse: 4.6131e-04
# Epoch 45: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 4.4409e-04 - mse: 4.4409e-04 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 46/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5516e-04 - mse: 4.5516e-04
# Epoch 46: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 4.3786e-04 - mse: 4.3786e-04 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 47/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5353e-04 - mse: 4.5353e-04
# Epoch 47: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 79s 14ms/step - loss: 4.3604e-04 - mse: 4.3604e-04 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 48/100
# 2888/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.4951e-04 - mse: 4.4951e-04
# Epoch 48: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 4.3211e-04 - mse: 4.3211e-04 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 49/100
# 2889/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4816e-04 - mse: 4.4816e-04
# Epoch 49: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - loss: 4.2891e-04 - mse: 4.2891e-04 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 50/100
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4480e-04 - mse: 4.4480e-04
# Epoch 50: val_loss did not improve from 0.00343
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - loss: 4.2848e-04 - mse: 4.2848e-04 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 50: early stopping
# ---Training time: 2040.18332958 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict(X_train)
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict(X_val)
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict(x_test)
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))

# Print RSME Results
print("RMSE scores: Train (SS) - %0.5f" %(train_rmse_SS))
print("RMSE scores: Validation (SS) - %0.5f" %(val_rmse_SS))
print("RMSE scores: Testing (SS) - %0.5f" %(test_rmse_SS))
# Out:
# 2890/2890 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 826/826 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step
# R2 scores: Train (SS) - 0.97416
# R2 scores: Validation (SS) - 0.88187
# R2 scores: Testing (SS) - 0.58269
# RMSE scores: Train (SS) - 0.02621
# RMSE scores: Validation (SS) - 0.06467
# RMSE scores: Testing (SS) - 0.11907
