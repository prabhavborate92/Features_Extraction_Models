# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt
np.random.seed(40)
tf.random.set_seed(40)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270_Data.mat')
data2 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270MechData.mat')
a_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2), 'freqQAmpI_filt':data1['freqQAmpI_filt'].ravel()})
w_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2),'C_filt':data1['C_filt'].ravel()})
m_t = pd.DataFrame({'Time':data1['Time'].ravel().round(2), 'SS':data1['SS'].ravel()})
s_t = pd.DataFrame({'Time':data2['Time'].ravel().round(2), 'V':data2['V'].ravel(),'V_filt':data2['V_filt'].ravel()})
df = a_t.merge(w_t, on='Time')
df = df.merge(m_t, on='Time')
df = df.merge(s_t, on='Time')
df = df[['freqQAmpI_filt','Time','SS']]
df_SS = df[['freqQAmpI_filt','SS']]
df_A = df[['freqQAmpI_filt','freqQAmpI_filt']]
xdf = df[['freqQAmpI_filt']]
ydf = df[['SS']]

df_SS = df_SS[0:100000]
df_A = df_A[0:100000]
xdf = xdf[0:100000]
ydf = ydf[0:100000]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#         freqQAmpI_filt
# 0        31453.223522
# 1        31438.277060
# 2        31421.341616
# 3        31409.798761
# 4        31398.815589
# ...               ...
# 99995    30869.698791
# 99996    30863.630877
# 99997    30859.759206
# 99998    30859.287324
# 99999    30844.600734
#
# [100000 rows x 1 columns]
# Target Data:
#               SS
# 0      5.656166
# 1      5.657157
# 2      5.658317
# 3      5.659499
# 4      5.660404
# ...         ...
# 99995  5.777328
# 99996  5.778124
# 99997  5.778968
# 99998  5.779630
# 99999  5.780332
#
# [100000 rows x 1 columns]

# %%
# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (A)
arr = df_A.to_numpy()
n_steps = 300
xdf, ydf_A = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (99700, 300, 1)
# Target shape (SS), Y =  (99700,)
# After reshaping, X =  (99700, 300)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 69790
# Validation samples: 9970
# Testing samples: 19940

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %% [markdown]
# **Define Data-Driven Model**

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer= tf.keras.optimizers.legacy.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  X_train (InputLayer)        [(None, 300)]             0
#
#  dense (Dense)               (None, 128)               38528
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 8)                 136
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 49537 (193.50 KB)
# Trainable params: 49537 (193.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 69790 samples, validate on 9970 samples
# Epoch 1/100
# 69568/69790 [============================>.] - ETA: 0s - loss: 0.0287 - mse: 0.0287
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 1: val_loss improved from inf to 0.01480, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 15s 216us/sample - loss: 0.0287 - mse: 0.0287 - val_loss: 0.0148 - val_mse: 0.0148
# Epoch 2/100
# 69440/69790 [============================>.] - ETA: 0s - loss: 0.0087 - mse: 0.0087
# Epoch 2: val_loss improved from 0.01480 to 0.00788, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 9s 127us/sample - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 3/100
# 69790/69790 [==============================] - ETA: 0s - loss: 0.0057 - mse: 0.0057
# Epoch 3: val_loss improved from 0.00788 to 0.00593, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 8s 113us/sample - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 4/100
# 69536/69790 [============================>.] - ETA: 0s - loss: 0.0045 - mse: 0.0045
# Epoch 4: val_loss improved from 0.00593 to 0.00336, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 10s 138us/sample - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 5/100
# 69504/69790 [============================>.] - ETA: 0s - loss: 0.0039 - mse: 0.0039
# Epoch 5: val_loss improved from 0.00336 to 0.00291, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 8s 108us/sample - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 6/100
# 69440/69790 [============================>.] - ETA: 0s - loss: 0.0041 - mse: 0.0041
# Epoch 6: val_loss did not improve from 0.00291
# 69790/69790 [==============================] - 8s 120us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 7/100
# 69504/69790 [============================>.] - ETA: 0s - loss: 0.0034 - mse: 0.0034
# Epoch 7: val_loss did not improve from 0.00291
# 69790/69790 [==============================] - 6s 82us/sample - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 8/100
# 69440/69790 [============================>.] - ETA: 0s - loss: 0.0033 - mse: 0.0033
# Epoch 8: val_loss did not improve from 0.00291
# 69790/69790 [==============================] - 6s 93us/sample - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 9/100
# 69312/69790 [============================>.] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 9: val_loss improved from 0.00291 to 0.00283, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 9s 128us/sample - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 10/100
# 69568/69790 [============================>.] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 10: val_loss did not improve from 0.00283
# 69790/69790 [==============================] - 6s 91us/sample - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 11/100
# 69760/69790 [============================>.] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 11: val_loss improved from 0.00283 to 0.00276, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 10s 144us/sample - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 12/100
# 69408/69790 [============================>.] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 12: val_loss improved from 0.00276 to 0.00259, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 9s 127us/sample - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 13/100
# 69760/69790 [============================>.] - ETA: 0s - loss: 0.0027 - mse: 0.0027
# Epoch 13: val_loss improved from 0.00259 to 0.00241, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 9s 136us/sample - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 14/100
# 69376/69790 [============================>.] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 14: val_loss improved from 0.00241 to 0.00210, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 10s 139us/sample - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 15/100
# 69312/69790 [============================>.] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 15: val_loss did not improve from 0.00210
# 69790/69790 [==============================] - 8s 118us/sample - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 16/100
# 69504/69790 [============================>.] - ETA: 0s - loss: 0.0026 - mse: 0.0026
# Epoch 16: val_loss did not improve from 0.00210
# 69790/69790 [==============================] - 8s 112us/sample - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 17/100
# 69248/69790 [============================>.] - ETA: 0s - loss: 0.0037 - mse: 0.0037
# Epoch 17: val_loss did not improve from 0.00210
# 69790/69790 [==============================] - 6s 91us/sample - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 18/100
# 69600/69790 [============================>.] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 18: val_loss did not improve from 0.00210
# 69790/69790 [==============================] - 7s 96us/sample - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 19/100
# 69152/69790 [============================>.] - ETA: 0s - loss: 0.0025 - mse: 0.0025
# Epoch 19: val_loss did not improve from 0.00210
# 69790/69790 [==============================] - 8s 110us/sample - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 20/100
# 69312/69790 [============================>.] - ETA: 0s - loss: 0.0024 - mse: 0.0024
# Epoch 20: val_loss improved from 0.00210 to 0.00202, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 7s 106us/sample - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 21/100
# 69568/69790 [============================>.] - ETA: 0s - loss: 0.0024 - mse: 0.0024
# Epoch 21: val_loss did not improve from 0.00202
# 69790/69790 [==============================] - 8s 119us/sample - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 22/100
# 69344/69790 [============================>.] - ETA: 0s - loss: 0.0023 - mse: 0.0023
# Epoch 22: val_loss did not improve from 0.00202
# 69790/69790 [==============================] - 6s 88us/sample - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 23/100
# 69728/69790 [============================>.] - ETA: 0s - loss: 0.0023 - mse: 0.0023
# Epoch 23: val_loss did not improve from 0.00202
# 69790/69790 [==============================] - 8s 117us/sample - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 24/100
# 69312/69790 [============================>.] - ETA: 0s - loss: 0.0021 - mse: 0.0021
# Epoch 24: val_loss did not improve from 0.00202
# 69790/69790 [==============================] - 6s 89us/sample - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 25/100
# 69728/69790 [============================>.] - ETA: 0s - loss: 0.0023 - mse: 0.0023
# Epoch 25: val_loss did not improve from 0.00202
# 69790/69790 [==============================] - 7s 106us/sample - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 26/100
# 69568/69790 [============================>.] - ETA: 0s - loss: 0.0022 - mse: 0.0022
# Epoch 26: val_loss did not improve from 0.00202
# 69790/69790 [==============================] - 7s 105us/sample - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 27/100
# 69440/69790 [============================>.] - ETA: 0s - loss: 0.0021 - mse: 0.0021
# Epoch 27: val_loss improved from 0.00202 to 0.00186, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check
# 69790/69790 [==============================] - 10s 150us/sample - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 28/100
# 69376/69790 [============================>.] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 28: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 7s 95us/sample - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 29/100
# 69760/69790 [============================>.] - ETA: 0s - loss: 0.0021 - mse: 0.0021
# Epoch 29: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 7s 107us/sample - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 30/100
# 69696/69790 [============================>.] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 30: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 9s 133us/sample - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 31/100
# 69790/69790 [==============================] - ETA: 0s - loss: 0.0019 - mse: 0.0019
# Epoch 31: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 8s 116us/sample - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 32/100
# 69184/69790 [============================>.] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 32: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 7s 102us/sample - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 33/100
# 69790/69790 [==============================] - ETA: 0s - loss: 0.0021 - mse: 0.0021
# Epoch 33: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 6s 93us/sample - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 34/100
# 69696/69790 [============================>.] - ETA: 0s - loss: 0.0019 - mse: 0.0019
# Epoch 34: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 8s 121us/sample - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 35/100
# 69408/69790 [============================>.] - ETA: 0s - loss: 0.0018 - mse: 0.0018
# Epoch 35: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 6s 91us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 36/100
# 69760/69790 [============================>.] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 36: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 9s 124us/sample - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 37/100
# 69504/69790 [============================>.] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 37: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 6s 92us/sample - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 38/100
# 69790/69790 [==============================] - ETA: 0s - loss: 0.0017 - mse: 0.0017
# Epoch 38: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 8s 112us/sample - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 39/100
# 69440/69790 [============================>.] - ETA: 0s - loss: 0.0018 - mse: 0.0018
# Epoch 39: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 6s 92us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 40/100
# 69504/69790 [============================>.] - ETA: 0s - loss: 0.0017 - mse: 0.0017
# Epoch 40: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 6s 91us/sample - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 41/100
# 69184/69790 [============================>.] - ETA: 0s - loss: 0.0019 - mse: 0.0019
# Epoch 41: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 8s 109us/sample - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 42/100
# 69280/69790 [============================>.] - ETA: 0s - loss: 0.0019 - mse: 0.0019
# Epoch 42: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 6s 86us/sample - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 43/100
# 69536/69790 [============================>.] - ETA: 0s - loss: 0.0017 - mse: 0.0017
# Epoch 43: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 8s 113us/sample - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 44/100
# 69344/69790 [============================>.] - ETA: 0s - loss: 0.0016 - mse: 0.0016
# Epoch 44: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 6s 86us/sample - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 45/100
# 69536/69790 [============================>.] - ETA: 0s - loss: 0.0018 - mse: 0.0018
# Epoch 45: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 6s 90us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 46/100
# 69568/69790 [============================>.] - ETA: 0s - loss: 0.0017 - mse: 0.0017
# Epoch 46: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 9s 131us/sample - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 47/100
# 69696/69790 [============================>.] - ETA: 0s - loss: 0.0017 - mse: 0.0017
# Epoch 47: val_loss did not improve from 0.00186
# 69790/69790 [==============================] - 7s 104us/sample - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 47: early stopping
# ---Training time: 368.29500103 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train])
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict([X_val])
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Model Performance: Testing
y_predtest = model.predict([x_test])
y_predtest_SS =np.array(y_predtest)

test_r2_SS = r2_score(y_test_SS,y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
print("R2 scores: Testing (SS) - %0.5f" %(test_r2_SS))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# R2 scores: Train (SS) - 0.94626
# R2 scores: Validation (SS) - 0.90993
# R2 scores: Testing (SS) - 0.86643
