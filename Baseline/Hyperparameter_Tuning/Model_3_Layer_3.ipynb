# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
# tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270_Data.mat')
data2 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270MechData.mat')
a_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2), 'freqQAmpI_filt':data1['freqQAmpI_filt'].ravel()})
w_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2),'C_filt':data1['C_filt'].ravel()})
m_t = pd.DataFrame({'Time':data1['Time'].ravel().round(2), 'SS':data1['SS'].ravel()})
s_t = pd.DataFrame({'Time':data2['Time'].ravel().round(2), 'V':data2['V'].ravel(),'V_filt':data2['V_filt'].ravel()})
df = a_t.merge(w_t, on='Time')
df = df.merge(m_t, on='Time')
df = df.merge(s_t, on='Time')
df = df[['freqQAmpI_filt','Time','SS']]
df_SS = df[['freqQAmpI_filt','SS']]
df_A = df[['freqQAmpI_filt','freqQAmpI_filt']]
xdf = df[['freqQAmpI_filt']]
ydf = df[['SS']]

df_SS = df_SS[0:100000]
df_A = df_A[0:100000]
xdf = xdf[0:100000]
ydf = ydf[0:100000]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#         freqQAmpI_filt
# 0        31453.223522
# 1        31438.277060
# 2        31421.341616
# 3        31409.798761
# 4        31398.815589
# ...               ...
# 99995    30869.698791
# 99996    30863.630877
# 99997    30859.759206
# 99998    30859.287324
# 99999    30844.600734
#
# [100000 rows x 1 columns]
# Target Data:
#               SS
# 0      5.656166
# 1      5.657157
# 2      5.658317
# 3      5.659499
# 4      5.660404
# ...         ...
# 99995  5.777328
# 99996  5.778124
# 99997  5.778968
# 99998  5.779630
# 99999  5.780332
#
# [100000 rows x 1 columns]

# %%
# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (A)
arr = df_A.to_numpy()
n_steps = 300
xdf, ydf_A = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (99700, 300, 1)
# Target shape (SS), Y =  (99700,)
# After reshaping, X =  (99700, 300)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 69790
# Validation samples: 9970
# Testing samples: 19940

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %% [markdown]
# **Define Data-Driven Model**

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(32,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8,kernel_initializer = 'normal', activation="relu")(x)
  # x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  # x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer= tf.keras.optimizers.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 42,929 (167.69 KB)
#  Trainable params: 42,929 (167.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 2163/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0731 - mse: 0.0731
# Epoch 1: val_loss improved from inf to 0.01781, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0727 - mse: 0.0727 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 2/100
# 2172/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0116 - mse: 0.0116
# Epoch 2: val_loss improved from 0.01781 to 0.00978, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 3/100
# 2170/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - mse: 0.0073
# Epoch 3: val_loss improved from 0.00978 to 0.00746, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 4/100
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - mse: 0.0054
# Epoch 4: val_loss improved from 0.00746 to 0.00663, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 5/100
# 2158/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mse: 0.0042
# Epoch 5: val_loss improved from 0.00663 to 0.00585, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 6/100
# 2175/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 6: val_loss improved from 0.00585 to 0.00455, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 7/100
# 2174/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 7: val_loss improved from 0.00455 to 0.00368, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 8/100
# 2180/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 8: val_loss improved from 0.00368 to 0.00298, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 9/100
# 2174/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 9: val_loss improved from 0.00298 to 0.00263, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 10/100
# 2177/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 10: val_loss improved from 0.00263 to 0.00260, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 11/100
# 2178/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 11: val_loss improved from 0.00260 to 0.00257, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 12/100
# 2176/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 12: val_loss improved from 0.00257 to 0.00249, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 13/100
# 2163/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 13: val_loss improved from 0.00249 to 0.00221, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 14/100
# 2162/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 14: val_loss improved from 0.00221 to 0.00218, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 15/100
# 2161/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 15: val_loss improved from 0.00218 to 0.00215, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 16/100
# 2162/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 16: val_loss improved from 0.00215 to 0.00213, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 17/100
# 2164/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 17: val_loss improved from 0.00213 to 0.00204, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 18/100
# 2177/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 18: val_loss improved from 0.00204 to 0.00195, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check.keras
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 19/100
# 2180/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 19: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 20/100
# 2161/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mse: 0.0023
# Epoch 20: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 21/100
# 2171/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 21: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 22/100
# 2160/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 22: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 23/100
# 2169/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 23: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 24/100
# 2175/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 24: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 25/100
# 2166/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 25: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 26/100
# 2175/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 26: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 27/100
# 2180/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 27: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 28/100
# 2174/2181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 28: val_loss did not improve from 0.00195
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 28: early stopping
# ---Training time: 260.04175639 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train])
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict([X_val])
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
# Out:
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R2 scores: Train (SS) - 0.92513
# R2 scores: Validation (SS) - 0.92677
