# %%
# Load Libraries
import pandas as pd
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
# tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Load the data
data1 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270_Data.mat')
data2 = loadmat('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data/p5270MechData.mat')
a_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2), 'freqQAmpI_filt':data1['freqQAmpI_filt'].ravel()})
w_t = pd.DataFrame({'Time':data1['LocalAcTime'].ravel().round(2),'C_filt':data1['C_filt'].ravel()})
m_t = pd.DataFrame({'Time':data1['Time'].ravel().round(2), 'SS':data1['SS'].ravel()})
s_t = pd.DataFrame({'Time':data2['Time'].ravel().round(2), 'V':data2['V'].ravel(),'V_filt':data2['V_filt'].ravel()})
df = a_t.merge(w_t, on='Time')
df = df.merge(m_t, on='Time')
df = df.merge(s_t, on='Time')
df = df[['freqQAmpI_filt','Time','SS']]
df_SS = df[['freqQAmpI_filt','SS']]
df_A = df[['freqQAmpI_filt','freqQAmpI_filt']]
xdf = df[['freqQAmpI_filt']]
ydf = df[['SS']]

df_SS = df_SS[0:100000]
df_A = df_A[0:100000]
xdf = xdf[0:100000]
ydf = ydf[0:100000]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#         freqQAmpI_filt
# 0        31453.223522
# 1        31438.277060
# 2        31421.341616
# 3        31409.798761
# 4        31398.815589
# ...               ...
# 99995    30869.698791
# 99996    30863.630877
# 99997    30859.759206
# 99998    30859.287324
# 99999    30844.600734
#
# [100000 rows x 1 columns]
# Target Data:
#               SS
# 0      5.656166
# 1      5.657157
# 2      5.658317
# 3      5.659499
# 4      5.660404
# ...         ...
# 99995  5.777328
# 99996  5.778124
# 99997  5.778968
# 99998  5.779630
# 99999  5.780332
#
# [100000 rows x 1 columns]

# %%
# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 300
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (A)
arr = df_A.to_numpy()
n_steps = 300
xdf, ydf_A = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (99700, 300, 1)
# Target shape (SS), Y =  (99700,)
# After reshaping, X =  (99700, 300)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 69790
# Validation samples: 9970
# Testing samples: 19940

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler()
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %% [markdown]
# **Define Data-Driven Model**

# %%
# Define DD
def MLP_Data():

  # Define inputs
  X_train = layers.Input(shape=(300,),name='X_train')

  # Prediction: Shear Stress + Slip Rate
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(32,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8,kernel_initializer = 'normal', activation="relu")(x)
  # x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  # x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred])
  return model

# %%
# Model Summary
model=MLP_Data()
model.compile(loss='mse', optimizer= tf.keras.optimizers.Adam(1e-2), metrics=['mse'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ X_train (InputLayer)            │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 42,929 (167.69 KB)
#  Trainable params: 42,929 (167.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train The Model
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [earlystop, checkpoint]
start_time = time.time()
history = model.fit([X_train],[Y_train_SS], epochs=100, batch_size=64,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS]), verbose=1)
end_time = time.time()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Epoch 1/100
# 1086/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0470 - mse: 0.0470
# Epoch 1: val_loss improved from inf to 0.01713, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0468 - mse: 0.0468 - val_loss: 0.0171 - val_mse: 0.0171
# Epoch 2/100
# 1071/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0154 - mse: 0.0154
# Epoch 2: val_loss improved from 0.01713 to 0.01567, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 3/100
# 1073/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0130 - mse: 0.0130
# Epoch 3: val_loss improved from 0.01567 to 0.01219, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 4/100
# 1082/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - mse: 0.0088
# Epoch 4: val_loss improved from 0.01219 to 0.00938, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 5/100
# 1076/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - mse: 0.0074
# Epoch 5: val_loss improved from 0.00938 to 0.00910, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 6/100
# 1077/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - mse: 0.0070
# Epoch 6: val_loss improved from 0.00910 to 0.00685, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 7/100
# 1090/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mse: 0.0057
# Epoch 7: val_loss did not improve from 0.00685
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 8/100
# 1077/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 8: val_loss improved from 0.00685 to 0.00526, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 9/100
# 1070/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mse: 0.0044
# Epoch 9: val_loss improved from 0.00526 to 0.00387, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 10/100
# 1084/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mse: 0.0039
# Epoch 10: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 11/100
# 1090/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mse: 0.0039
# Epoch 11: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 12/100
# 1082/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mse: 0.0039
# Epoch 12: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 13/100
# 1076/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 13: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 14/100
# 1088/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 14: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 15/100
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 15: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 16/100
# 1079/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 16: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 17/100
# 1089/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 17: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 18/100
# 1086/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 18: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 19/100
# 1086/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 19: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 20/100
# 1087/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 20: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 21/100
# 1077/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 21: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 22/100
# 1084/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 22: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 23/100
# 1084/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 23: val_loss did not improve from 0.00387
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 24/100
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 24: val_loss improved from 0.00387 to 0.00385, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 25/100
# 1079/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 25: val_loss did not improve from 0.00385
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 26/100
# 1077/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 26: val_loss did not improve from 0.00385
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 27/100
# 1078/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 27: val_loss did not improve from 0.00385
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 28/100
# 1090/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 28: val_loss did not improve from 0.00385
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 29/100
# 1086/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 29: val_loss did not improve from 0.00385
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 30/100
# 1088/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 30: val_loss improved from 0.00385 to 0.00384, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 31/100
# 1082/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 31: val_loss did not improve from 0.00384
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 32/100
# 1078/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 32: val_loss did not improve from 0.00384
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 33/100
# 1089/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 33: val_loss improved from 0.00384 to 0.00383, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 34/100
# 1079/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 34: val_loss did not improve from 0.00383
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 35/100
# 1084/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 35: val_loss did not improve from 0.00383
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 36/100
# 1083/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 36: val_loss did not improve from 0.00383
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 37/100
# 1081/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 37: val_loss did not improve from 0.00383
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 38/100
# 1084/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 38: val_loss did not improve from 0.00383
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 39/100
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 39: val_loss improved from 0.00383 to 0.00377, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 40/100
# 1088/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 40: val_loss improved from 0.00377 to 0.00350, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 41/100
# 1084/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 41: val_loss did not improve from 0.00350
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 42/100
# 1075/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 42: val_loss improved from 0.00350 to 0.00335, saving model to /content/drive/My Drive/Colab Notebooks/PINN_Paper_Codes/New_Models/Reference_p5270/Data-driven/Check1.keras
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 43/100
# 1083/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 43: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 44/100
# 1074/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 44: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 45/100
# 1081/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 45: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 46/100
# 1082/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 46: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 47/100
# 1076/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 47: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 48/100
# 1077/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 48: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 49/100
# 1075/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 49: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 50/100
# 1084/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 50: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 51/100
# 1086/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 51: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 52/100
# 1075/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 52: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 53/100
# 1084/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 53: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 54/100
# 1086/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 54: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 55/100
# 1090/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 55: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 56/100
# 1088/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 56: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 57/100
# 1089/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 57: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 58/100
# 1079/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 58: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 59/100
# 1078/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 59: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 60/100
# 1087/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 60: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 61/100
# 1080/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 61: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 62/100
# 1079/1091 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 62: val_loss did not improve from 0.00335
# 1091/1091 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 62: early stopping
# ---Training time: 270.55280519 seconds ---

# %%
# Model Performance: Training
y_predtrain = model.predict([X_train])
y_predtrain_SS = np.array(y_predtrain)

train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

# Model Performance: Validation
y_predval = model.predict([X_val])
y_predval_SS = np.array(y_predval)

val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

# Print R2 Results
print("R2 scores: Train (SS) - %0.5f" %(train_r2_SS))
print("R2 scores: Validation (SS) - %0.5f" %(val_r2_SS))
# Out:
# 2181/2181 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R2 scores: Train (SS) - 0.88049
# R2 scores: Validation (SS) - 0.78009
